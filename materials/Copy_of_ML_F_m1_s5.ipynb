# %% [markdown]
# **Работа с большими объемами данных**

# %% [markdown]
# ### Малые данные
#
# Малые данные представляют собой ограниченные наборы данных, которые могут быть легко обработаны и проанализированы с использованием традиционных инструментов и методов. Они часто структурированы и могут быть представлены в виде таблиц или баз данных. Примеры малых данных включают:
# - Финансовые отчеты компаний
# - Ежедневные транзакции
# - Исторические данные по акциям
#
# ### Большие данные
#
# Большие данные, с другой стороны, характеризуются объемом, разнообразием и скоростью. Они требуют использования специализированных технологий и фреймворков для обработки и анализа. Большие данные могут быть как структурированными, так и неструктурированными, и включают:
# - Потоки данных с финансовых рынков в реальном времени
# - Социальные медиа и новостные ленты
# - Данные о поведении клиентов и транзакциях
#
# ### Основные различия
#
# 1. **Объем**: Малые данные обычно имеют ограниченный объем, в то время как большие данные могут достигать терабайтов и петабайтов.
# 2. **Скорость**: Большие данные часто поступают в реальном времени, требуя мгновенной обработки, в отличие от малых данных, которые могут быть обработаны в пакетном режиме.
# 3. **Разнообразие**: Большие данные могут включать текст, изображения, видео и другие форматы, тогда как малые данные обычно структурированы.

# %% [markdown]
# # Управление данными и кэширование в финансовых приложениях
#
# В этом разделе мы рассмотрим, как использовать **Redis** для управления состоянием и кэшированием данных в финансовых приложениях. Эти [инструменты](https://db-engines.com/en/ranking) позволяют эффективно обрабатывать большие объемы данных, обеспечивая высокую производительность и надежность систем.

# %%
# %%capture
# !apt-get update
# !apt-get install -y redis-server
# !redis-server --daemonize yes # Запуск Redis в фоновом режиме
# !redis-server --version

# %% [markdown]
# ## Пример использования Redis для кэширования данных
#
# В этом примере мы создадим простое приложение на Python, которое будет использовать Redis для кэширования результатов вычислений. Это позволит ускорить доступ к часто запрашиваемым данным.
#
# ### Преимущества использования Redis в финансовых приложениях:
# - **Высокая скорость**: Данные хранятся в оперативной памяти, что обеспечивает быстрый доступ.
# - **Поддержка различных структур данных**: Позволяет хранить и обрабатывать данные в удобной форме.
# - **Масштабируемость**: Легко масштабируется для обработки больших объемов данных.
# - **Надежность**: Поддерживает механизмы репликации и персистентности данных.

# %%
# %%capture
# !pip install redis
import redis

r = redis.Redis(host='localhost', port=6379, db=0) # Создаем объект подключения к Redis

# %%
redis.__version__
# Out:
# '6.2.0'

# %%
import pandas as pd
import numpy as np
import timeit

from math import sin

# %%
# Функция для вычисления и кэширования данных
def expensive_computation(x):
    # Проверяем, есть ли результат в кэше
    if r.exists(f'computation:{x[0]}'):
        #print('есть результат в кэше !')
        return r.get(f'computation:{x[0]}')
    else:
        #print('нет в кеше, делаем вычисления')
        result = float([sin(i**2) ** 2 for i in x][0])  # Пример сложных вычислений
        r.set(f'computation:{x[0]}', result) # Сохраняем результат в кэше
        return result

print(f"-кеширование, 1-ый запуск")
# %timeit -n1 -r1 expensive_computation([5])
print(f"+кеширование, 2-ый запуск")
# %timeit expensive_computation([5])
# Out:
# -кеширование, 1-ый запуск
# 1.92 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# +кеширование, 2-ый запуск
# 230 µs ± 10.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ## Apache Spark
#
# Apache Spark — это распределенная вычислительная платформа с открытым исходным кодом, которая позволяет обрабатывать большие объемы данных с высокой скоростью. Spark поддерживает различные языки программирования, включая Python, Java и Scala, и предоставляет API для работы с данными в режиме реального времени и пакетной обработки.
#
# ### Основные компоненты Apache Spark:
# - **Spark Core**: Основной компонент, отвечающий за распределенные вычисления и управление ресурсами.
# - **Spark SQL**: Модуль для работы с данными в формате SQL, который позволяет выполнять запросы к данным, хранящимся в различных источниках.
# - **Spark Streaming**: Модуль для обработки потоковых данных в реальном времени.
# - **MLlib**: Библиотека машинного обучения, предоставляющая алгоритмы для анализа данных.
# - **GraphX**: API для работы с графами и выполнения графовых вычислений.

# %%
! RESTART SESSION

# %%
# !pip freeze > freeze.txt

# %%
# %%capture
# !pip install pyspark # Устанавливаем PySpark, интерфейс для работы со Spark на Python
# !wget https://drive.google.com/uc?id=11V38AUYhTokBYaRf9Glr0isuqrSeuzqx -O /content/EURUSD_Candlestick_1_Hour_BID_01.07.2020-15.07.2023.csv

# %%
from pyspark.sql import SparkSession # Импортируем SparkSession из PySpark

# Создаем SparkSession
spark = SparkSession.builder \
    .appName("FinanceDataProcessing") \
    .config("spark.executor.memory", "4g") \
    .getOrCreate()

# Указываем путь к нашему датасету
s3_path = "/content/EURUSD_Candlestick_1_Hour_BID_01.07.2020-15.07.2023.csv"
# Загружаем датасет в DataFrame
sdf = spark.read.csv(s3_path, header=True, inferSchema=True)

# Выводим схему загруженного DataFrame
sdf.printSchema()
# Out:
# root
#  |-- Gmt time: string (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: double (nullable = true)

# %%
sdf.select("Open", "High", "Low", "Close", "Volume").describe().show()
# Out:
# +-------+-------------------+-------------------+-------------------+-------------------+--------------------+
# |summary|               Open|               High|                Low|              Close|              Volume|
# +-------+-------------------+-------------------+-------------------+-------------------+--------------------+
# |  count|              17768|              17768|              17768|              17768|               17768|
# |   mean| 1.1246986346240468| 1.1254486104232424| 1.1239660214993197| 1.1247025866726719|  11686.864068479525|
# | stddev|0.06896329376638866|0.06882445176700097|0.06908021172626208|0.06895785696887373|   16224.18962253226|
# |    min|             0.9539|            0.95592|            0.95357|             0.9539|2.293899999999999...|
# |    max|            1.23398|            1.23494|            1.23334|            1.23401|         688879.8125|
# +-------+-------------------+-------------------+-------------------+-------------------+--------------------+

# %%
# создадим гибрид pandas-on-Spark используя Spark DataFrame.
psdf = sdf.pandas_api()
psdf.describe()

# %%
import pandas as pd
import numpy as np
import pyspark.pandas as ps
import os
import warnings
warnings.filterwarnings("ignore")
os.environ["PYARROW_IGNORE_TIMEZONE"]="false"
pdf = pd.read_csv(s3_path)
pdf.drop(["Gmt time","Volume"],axis=1)

prev = spark.conf.get("spark.sql.execution.arrow.pyspark.enabled")
ps.set_option("compute.default_index_type", "distributed")
print("формат Arrow оптимизирует хранение данных в памяти, поддерживает быструю передачу данных по сети.")
print("выключить Arrow")
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", False)
# %timeit ps.range(300000).to_pandas()
print("включить Arrow")
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", True)
# %timeit ps.range(300000).to_pandas()
ps.reset_option("compute.default_index_type")
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", prev)
# Out:
# /usr/local/lib/python3.11/dist-packages/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(
# формат Arrow оптимизирует хранение данных в памяти, поддерживает быструю передачу данных по сети.
# выключить Arrow
# 2.39 s ± 584 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# включить Arrow
# 324 ms ± 36.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
spark = SparkSession.builder.master("local[*]").appName("BigDataFinance").getOrCreate() # Создаем локальную сессию
spark # Выводим информацию о созданной сессии
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://13ac52e5011a:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>FinanceDataProcessing</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
print(psdf.head())
def add(data):return data[2] / data[3]  #вычисляем индикатор High/Low
# psdf["индикатор"] = psdf.apply(add,axis=1) не сработает
new_column = psdf.apply(add,axis=1)
print(new_column.head())
# Out:
#                   Gmt time     Open     High      Low    Close     Volume
# 0  01.07.2020 00:00:00.000  1.12336  1.12336  1.12275  1.12306  4148.0298
# 1  01.07.2020 01:00:00.000  1.12306  1.12395  1.12288  1.12385  5375.5801
# 2  01.07.2020 02:00:00.000  1.12386  1.12406  1.12363  1.12382  4131.6099
# 3  01.07.2020 03:00:00.000  1.12382  1.12388  1.12221  1.12265  4440.6001
# 4  01.07.2020 04:00:00.000  1.12265  1.12272  1.12151  1.12179  4833.1001
# 0    1.000543
# 1    1.000953
# 2    1.000383
# 3    1.001488
# 4    1.001079
# dtype: float64

# %% [markdown]
# Подитожим преимущества использования датафрейма PySpark по сравнению с Pandas:
#
# <table>
# <thead>
# <tr>
# <th><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Spark DataFrame</font></font></th>
# <th><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Pandas DataFrame</font></font></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Spark DataFrame поддерживает распараллеливание.&nbsp;</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Pandas DataFrame не поддерживает распараллеливание.&nbsp;</font></font></td>
# </tr>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Spark DataFrame имеет несколько узлов.</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Pandas DataFrame имеет один узел.</font></font></td>
# </tr>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;" class="">Он следует принципу ленивого выполнения - это означает,<br> что задача не выполняется до тех пор, пока не будет выполнено действие.</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Он следует принципу Eager Execution, что означает, что задача выполняется немедленно.</font></font></td>
# </tr>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Spark DataFrame является неизменяемым.</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Pandas DataFrame является изменяемым.</font></font></td>
# </tr>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Сложные операции сложнее выполнять по сравнению с Pandas DataFrame.</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Сложные операции выполнять проще по сравнению со Spark DataFrame.</font></font></td>
# </tr>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Spark DataFrame является распределенным, <br>поэтому обработка в Spark DataFrame больших объемов данных происходит быстрее.</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Pandas DataFrame не является распределенным, <br>поэтому обработка в Pandas DataFrame больших объемов данных будет выполняться медленнее.</font></font></td>
# </tr>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">sparkDataFrame.count() возвращает количество строк.</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">pandasDataFrame.count() возвращает количество наблюдений, отличных от NA/null, для каждого столбца.</font></font></td>
# </tr>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Spark DataFrames отлично подходят для создания масштабируемых приложений.</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Pandas DataFrames нельзя использовать для создания масштабируемого приложения.</font></font></td>
# </tr>
# <tr>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Spark DataFrame обеспечивает отказоустойчивость.</font></font></td>
# <td><font style="vertical-align: inherit;"><font style="vertical-align: inherit;">Pandas DataFrame не гарантирует отказоустойчивость. <br>Для ее обеспечения нам необходимо реализовать собственную структуру.</font></font></td>
# </tr>
# </tbody>
# </table>
#
# В этом разделе мы рассмотрели, как загружать и предварительно обрабатывать большие финансовые датасеты с использованием PySpark, а также как использовать Trino для выполнения распределенных SQL-запросов. Эти инструменты позволяют эффективно работать с большими объемами данных и извлекать из них полезную информацию.

# %%
! RESTART SESSION

# %% [markdown]
# https://www.dask.org/

# %%
# !pip install dask
# !pip install dask-ml
# Out:
# Requirement already satisfied: dask in /usr/local/lib/python3.11/dist-packages (2025.5.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask) (2025.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask) (3.22.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask) (1.0.0)
# Requirement already satisfied: dask-ml in /usr/local/lib/python3.11/dist-packages (2025.1.0)
# Requirement already satisfied: dask-glm>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from dask-ml) (0.3.2)
# Requirement already satisfied: dask>=2025.1.0 in /usr/local/lib/python3.11/dist-packages (from dask[array,dataframe]>=2025.1.0->dask-ml) (2025.5.1)
# Requirement already satisfied: distributed>=2025.1.0 in /usr/local/lib/python3.11/dist-packages (from dask-ml) (2025.5.1)
# Requirement already satisfied: multipledispatch>=0.4.9 in /usr/local/lib/python3.11/dist-packages (from dask-ml) (1.0.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from dask-ml) (0.60.0)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from dask-ml) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from dask-ml) (24.2)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from dask-ml) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from dask-ml) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from dask-ml) (1.15.3)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2025.1.0->dask[array,dataframe]>=2025.1.0->dask-ml) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2025.1.0->dask[array,dataframe]>=2025.1.0->dask-ml) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2025.1.0->dask[array,dataframe]>=2025.1.0->dask-ml) (2025.3.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2025.1.0->dask[array,dataframe]>=2025.1.0->dask-ml) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2025.1.0->dask[array,dataframe]>=2025.1.0->dask-ml) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2025.1.0->dask[array,dataframe]>=2025.1.0->dask-ml) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2025.1.0->dask[array,dataframe]>=2025.1.0->dask-ml) (8.7.0)
# Requirement already satisfied: sparse>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from dask-glm>=0.2.0->dask-ml) (0.17.0)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask[array,dataframe]>=2025.1.0->dask-ml) (18.1.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (2.4.0)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from distributed>=2025.1.0->dask-ml) (3.0.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->dask-ml) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask-ml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask-ml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask-ml) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.1->dask-ml) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.1->dask-ml) (3.6.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask>=2025.1.0->dask[array,dataframe]>=2025.1.0->dask-ml) (3.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.10.3->distributed>=2025.1.0->dask-ml) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask-ml) (1.17.0)

# %%
import dask.dataframe as dd
from dask_ml.model_selection import train_test_split
from dask_ml.linear_model import LogisticRegression
from dask.distributed import Client
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

# %%
# Создаем клиент Dask для распределенных вычислений
client = Client()
# Out:
# INFO:distributed.http.proxy:To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:45795
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:40447'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:35121'
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:46613 name: 0
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:46613
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:58456
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:33677 name: 1
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:33677
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:58458
# INFO:distributed.scheduler:Receive client connection: Client-7aef6109-4add-11f0-97bc-0242ac1c000c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:58466

# %%
# Загружаем данные Ирисов Фишера
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Преобразуем данные в Pandas DataFrame
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y

# %%
# Преобразуем Pandas DataFrame в Dask DataFrame
ddf = dd.from_pandas(df, npartitions=2)

# %%
ddf
# Out:
# Dask DataFrame Structure:
#               sepal length (cm) sepal width (cm) petal length (cm) petal width (cm) target
# npartitions=2
# 0                       float64          float64           float64          float64  int64
# 75                          ...              ...               ...              ...    ...
# 149                         ...              ...               ...              ...    ...
# Dask Name: frompandas, 1 expression
# Expr=df

# %%
# Разделяем данные на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(ddf[iris.feature_names], ddf['target'], test_size=0.3, random_state=42, shuffle=True)

# %%
X_train = X_train.to_dask_array(lengths=True)
y_train = y_train.to_dask_array(lengths=True)
X_test = X_test.to_dask_array(lengths=True)
y_test = y_test.to_dask_array(lengths=True)

# %%
# Создаем модель логистической регрессии
model = LogisticRegression()

# %%
# Обучаем модель
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.decision_function(X_train)
# Out:
# dask.array<sum-aggregate, shape=(106,), dtype=float64, chunksize=(57,), chunktype=numpy.ndarray>

# %%
model.predict(X_test)
# Out:
# dask.array<gt, shape=(44,), dtype=bool, chunksize=(26,), chunktype=numpy.ndarray>

# %%
model.predict_proba(X_test)
# Out:
# dask.array<transpose, shape=(44, 2), dtype=float64, chunksize=(26, 1), chunktype=numpy.ndarray>

# %%
np.array(model.predict_proba(X_test))
# Out:
# array([[1.00000000e+00, 2.87838990e-50],
#        [1.00000000e+00, 2.29781215e-41],
#        [1.00000000e+00, 4.02563625e-42],
#        [1.00000000e+00, 5.49542915e-47],
#        [0.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 2.55778761e-44],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [4.44089210e-16, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 2.83081442e-42],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 4.43537147e-48],
#        [0.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 2.85876044e-44],
#        [1.00000000e+00, 2.09759718e-40],
#        [1.00000000e+00, 1.04621010e-36],
#        [1.00000000e+00, 2.32829149e-36],
#        [1.00000000e+00, 3.75555703e-41],
#        [0.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 6.84089286e-34],
#        [1.00000000e+00, 5.53392516e-42],
#        [7.77156117e-15, 1.00000000e+00],
#        [1.00000000e+00, 1.07124498e-39],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [5.42521727e-01, 4.57478273e-01],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00]])

# %%
model.score(X_test, y_test)
# Out:
# dask.array<mean_agg-aggregate, shape=(), dtype=float64, chunksize=(), chunktype=numpy.ndarray>

# %%
np.array(model.score(X_test, y_test))
# Out:
# array(0.65909091)

# %%
# Закрываем клиент Dask
client.close()
# Out:
# INFO:distributed.scheduler:Remove client Client-7aef6109-4add-11f0-97bc-0242ac1c000c
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:58466; closing.
# INFO:distributed.scheduler:Remove client Client-7aef6109-4add-11f0-97bc-0242ac1c000c
# INFO:distributed.scheduler:Close client connection: Client-7aef6109-4add-11f0-97bc-0242ac1c000c
# INFO:distributed.scheduler:Retire worker addresses (stimulus_id='retire-workers-1750097710.9056675') (0, 1)
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:40447'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:35121'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:58456; closing.
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:46613 name: 0 (stimulus_id='handle-worker-cleanup-1750097710.9176917')
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:58458; closing.
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:33677 name: 1 (stimulus_id='handle-worker-cleanup-1750097710.9240108')
# INFO:distributed.scheduler:Lost all workers
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:35121' closed.
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:40447' closed.
# INFO:distributed.scheduler:Closing scheduler. Reason: unknown
# INFO:distributed.scheduler:Scheduler closing all comms

# %%
from dask.distributed import Client
client = Client(n_workers=2, threads_per_worker=1)
client
# Out:
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:43411
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:33993'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:45377'
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:42045 name: 0
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:42045
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:39534
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:45307 name: 1
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:45307
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:39550
# INFO:distributed.scheduler:Receive client connection: Client-e306514d-4add-11f0-97bc-0242ac1c000c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:39564
# <Client: 'tcp://127.0.0.1:43411' processes=2 threads=2, memory=12.67 GiB>

# %%
# !pip3 install --upgrade yfinance > None

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %% [markdown]
# # Download Market Data from Yahoo! Finance’s API

# %%
# Получение данных:

# Указываем тикер ПАО "Газпром" на Московской бирже
ticker = "GAZP.ME"

# Создаем объект тикера
gazprom = yf.Ticker(ticker)

# Получение исторических данных по акциям ПАО "Газпром"
# period="max" означает получение всех доступных данных
historical_data = gazprom.history(period="max")

# %%
historical_data.index.max()
# Out:
# Timestamp('2022-10-10 00:00:00+0300', tz='Europe/Moscow')

# %%
historical_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-03-03 00:00:00+03:00   91.197370   92.418093   90.268327   91.877953
# 2010-03-04 00:00:00+03:00   91.289177   94.222146   90.943488   93.050041
# 2010-03-05 00:00:00+03:00   94.011493   95.907384   93.854847   95.496880
# 2010-03-09 00:00:00+03:00   95.394241   96.193646   94.168119   94.778481
# 2010-03-10 00:00:00+03:00   94.416604   95.988416   93.255297   93.860260
# ...                               ...         ...         ...         ...
# 2022-05-19 00:00:00+03:00  268.000000  269.779999  262.649994  266.679993
# 2022-05-20 00:00:00+03:00  266.679993  266.679993  266.679993  266.679993
# 2022-05-23 00:00:00+03:00  266.679993  266.679993  266.679993  266.679993
# 2022-05-24 00:00:00+03:00  266.679993  266.679993  266.679993  266.679993
# 2022-10-10 00:00:00+03:00         NaN         NaN         NaN         NaN
#
#                              Volume  Dividends  Stock Splits
# Date
# 2010-03-03 00:00:00+03:00  15012689       0.00           0.0
# 2010-03-04 00:00:00+03:00  22078020       0.00           0.0
# 2010-03-05 00:00:00+03:00  27804988       0.00           0.0
# 2010-03-09 00:00:00+03:00  20023702       0.00           0.0
# 2010-03-10 00:00:00+03:00  19300420       0.00           0.0
# ...                             ...        ...           ...
# 2022-05-19 00:00:00+03:00  24980910       0.00           0.0
# 2022-05-20 00:00:00+03:00         0       0.00           0.0
# 2022-05-23 00:00:00+03:00         0       0.00           0.0
# 2022-05-24 00:00:00+03:00         0       0.00           0.0
# 2022-10-10 00:00:00+03:00         0      51.03           0.0
#
# [3044 rows x 7 columns]

# %%
historical_data = historical_data.reset_index()
historical_data.to_csv('gazprom_historical_data.csv')

# %%
historical_data.to_parquet('df.parquet.gzip', compression='gzip')
pd.read_parquet('df.parquet.gzip')
# Out:
#                           Date        Open        High         Low  \
# 0    2010-03-03 00:00:00+03:00   91.197370   92.418093   90.268327
# 1    2010-03-04 00:00:00+03:00   91.289177   94.222146   90.943488
# 2    2010-03-05 00:00:00+03:00   94.011493   95.907384   93.854847
# 3    2010-03-09 00:00:00+03:00   95.394241   96.193646   94.168119
# 4    2010-03-10 00:00:00+03:00   94.416604   95.988416   93.255297
# ...                        ...         ...         ...         ...
# 3039 2022-05-19 00:00:00+03:00  268.000000  269.779999  262.649994
# 3040 2022-05-20 00:00:00+03:00  266.679993  266.679993  266.679993
# 3041 2022-05-23 00:00:00+03:00  266.679993  266.679993  266.679993
# 3042 2022-05-24 00:00:00+03:00  266.679993  266.679993  266.679993
# 3043 2022-10-10 00:00:00+03:00         NaN         NaN         NaN
#
#            Close    Volume  Dividends  Stock Splits
# 0      91.877953  15012689       0.00           0.0
# 1      93.050041  22078020       0.00           0.0
# 2      95.496880  27804988       0.00           0.0
# 3      94.778481  20023702       0.00           0.0
# 4      93.860260  19300420       0.00           0.0
# ...          ...       ...        ...           ...
# 3039  266.679993  24980910       0.00           0.0
# 3040  266.679993         0       0.00           0.0
# 3041  266.679993         0       0.00           0.0
# 3042  266.679993         0       0.00           0.0
# 3043         NaN         0      51.03           0.0
#
# [3044 rows x 8 columns]

# %%
historical_data.to_parquet('df.parquet')
pd.read_parquet('df.parquet')
# Out:
#                           Date        Open        High         Low  \
# 0    2010-03-03 00:00:00+03:00   91.197370   92.418093   90.268327
# 1    2010-03-04 00:00:00+03:00   91.289177   94.222146   90.943488
# 2    2010-03-05 00:00:00+03:00   94.011493   95.907384   93.854847
# 3    2010-03-09 00:00:00+03:00   95.394241   96.193646   94.168119
# 4    2010-03-10 00:00:00+03:00   94.416604   95.988416   93.255297
# ...                        ...         ...         ...         ...
# 3039 2022-05-19 00:00:00+03:00  268.000000  269.779999  262.649994
# 3040 2022-05-20 00:00:00+03:00  266.679993  266.679993  266.679993
# 3041 2022-05-23 00:00:00+03:00  266.679993  266.679993  266.679993
# 3042 2022-05-24 00:00:00+03:00  266.679993  266.679993  266.679993
# 3043 2022-10-10 00:00:00+03:00         NaN         NaN         NaN
#
#            Close    Volume  Dividends  Stock Splits
# 0      91.877953  15012689       0.00           0.0
# 1      93.050041  22078020       0.00           0.0
# 2      95.496880  27804988       0.00           0.0
# 3      94.778481  20023702       0.00           0.0
# 4      93.860260  19300420       0.00           0.0
# ...          ...       ...        ...           ...
# 3039  266.679993  24980910       0.00           0.0
# 3040  266.679993         0       0.00           0.0
# 3041  266.679993         0       0.00           0.0
# 3042  266.679993         0       0.00           0.0
# 3043         NaN         0      51.03           0.0
#
# [3044 rows x 8 columns]

# %% [markdown]
# # sqlite3

# %%
import sqlite3


# Создание базы данных:

# Создание базы данных и подключение
conn = sqlite3.connect('gazprom_data.db')

# Проверка подключения
print("База данных gazprom_data.db создана и подключена.")

# Закрытие соединения
conn.close()
# Out:
# База данных gazprom_data.db создана и подключена.

# %%
# Создание таблиц в базе данных:

# Подключение к базе данных
conn = sqlite3.connect('gazprom_data.db')
cursor = conn.cursor()

# Получение списка всех таблиц
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Удаление каждой таблицы, кроме системной таблицы sqlite_sequence
for table_name in tables:
    if table_name[0] != 'sqlite_sequence':  # Пропускаем системную таблицу
        print(f"Удаляем таблицу {table_name[0]}")
        cursor.execute(f"DROP TABLE IF EXISTS {table_name[0]}")

# Создание таблицы historical_data
cursor.execute('''
CREATE TABLE IF NOT EXISTS historical_data (
    date TEXT PRIMARY KEY,
    open REAL,
    high REAL,
    low REAL,
    close REAL,
    volume REAL,
    dividends REAL,
    stock_splits REAL
)
''')

# Закрытие соединения
conn.commit()
conn.close()

print("Таблицы созданы успешно.")
# Out:
# Таблицы созданы успешно.

# %%
conn = sqlite3.connect('gazprom_data.db')
cursor = conn.cursor()

# Получение исторических данных из базы данных
historical_data = pd.read_sql_query("SELECT * FROM historical_data", conn)
conn.close()
historical_data
# Out:
# Empty DataFrame
# Columns: [date, open, high, low, close, volume, dividends, stock_splits]
# Index: []

# %%
# Подключение к базе данных
conn = sqlite3.connect('gazprom_data.db')
cursor = conn.cursor()

# Функция для загрузки данных и проверки на дублирование
def insert_or_ignore(cursor, query, data):
    cursor.execute(query, data)

# Загрузка данных в таблицу historical_data
historical_data = pd.read_csv('gazprom_historical_data.csv')

# Явно указываем utc=True для корректного преобразования даты
historical_data['Date'] = pd.to_datetime(historical_data['Date'], utc=True).dt.date

for i, row in historical_data.iterrows():
    insert_or_ignore(cursor, '''
    INSERT OR IGNORE INTO historical_data (date, open, high, low, close, volume, dividends, stock_splits)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    ''', (row['Date'], row['Open'], row['High'], row['Low'], row['Close'], row['Volume'], row['Dividends'], row['Stock Splits']))

# Закрытие соединения
conn.commit()
conn.close()

print("Данные успешно загружены в таблицы.")
# Out:
# Данные успешно загружены в таблицы.

# %%
conn = sqlite3.connect('gazprom_data.db')
cursor = conn.cursor()

# Получение исторических данных из базы данных
historical_data = pd.read_sql_query("SELECT * FROM historical_data", conn)
conn.close()
historical_data
# Out:
#             date        open        high         low       close      volume  \
# 0     2010-03-02   91.197370   92.418093   90.268327   91.877953  15012689.0
# 1     2010-03-03   91.289177   94.222146   90.943488   93.050041  22078020.0
# 2     2010-03-04   94.011493   95.907384   93.854847   95.496880  27804988.0
# 3     2010-03-08   95.394241   96.193646   94.168119   94.778481  20023702.0
# 4     2010-03-09   94.416604   95.988416   93.255297   93.860260  19300420.0
# ...          ...         ...         ...         ...         ...         ...
# 3039  2022-05-18  268.000000  269.779999  262.649994  266.679993  24980910.0
# 3040  2022-05-19  266.679993  266.679993  266.679993  266.679993         0.0
# 3041  2022-05-22  266.679993  266.679993  266.679993  266.679993         0.0
# 3042  2022-05-23  266.679993  266.679993  266.679993  266.679993         0.0
# 3043  2022-10-09         NaN         NaN         NaN         NaN         0.0
#
#       dividends  stock_splits
# 0          0.00           0.0
# 1          0.00           0.0
# 2          0.00           0.0
# 3          0.00           0.0
# 4          0.00           0.0
# ...         ...           ...
# 3039       0.00           0.0
# 3040       0.00           0.0
# 3041       0.00           0.0
# 3042       0.00           0.0
# 3043      51.03           0.0
#
# [3044 rows x 8 columns]

# %%
# Пример кода для автоматического обновления данных в базе данных:

# Подключение к базе данных
conn = sqlite3.connect('gazprom_data.db')
cursor = conn.cursor()

# Функция для обновления данных в таблице historical_data
def update_historical_data():
    try:
        # Загрузка новых данных через yfinance (например, за последние 5 дней)
        #new_data = yf.download('GAZP.ME', period='1d')

        ticker = "GAZP.ME"
        gazprom = yf.Ticker(ticker)
        new_data = gazprom.history(period="max")

        if new_data.empty:
            print("Данные для GAZP.ME не найдены. Возможно, тикер был исключен с биржи.")
            return

        # Преобразование индекса в колонку Date
        new_data.reset_index(inplace=True)
        new_data['Date'] = pd.to_datetime(new_data['Date'], utc=True).dt.date

        # Обработка каждого ряда данных
        for i, row in new_data.iterrows():
            cursor.execute('SELECT 1 FROM historical_data WHERE date = ?', (row['Date'],))
            if cursor.fetchone() is None:
                cursor.execute('''
                INSERT INTO historical_data (date, open, high, low, close, volume, dividends, stock_splits)
                VALUES (?, ?, ?, ?, ?, ?, ?, ?)
                ''', (row['Date'], row['Open'], row['High'], row['Low'], row['Close'], row['Volume'], row.get('Dividends', 0), row.get('Stock Splits', 0)))
                print(f"Данные за {row['Date']} добавлены.")
            else:
                print(f"Данные за {row['Date']} уже существуют.")
    except Exception as e:
        print(f"Ошибка при обновлении исторических данных: {e}")

# Запуск обновления данных
update_historical_data()

# Закрытие соединения с базой данных после обновления
conn.commit()
conn.close()
# Out:
# Данные за 2010-03-02 уже существуют.
# Данные за 2010-03-03 уже существуют.
# Данные за 2010-03-04 уже существуют.
# Данные за 2010-03-08 уже существуют.
# Данные за 2010-03-09 уже существуют.
# Данные за 2010-03-10 уже существуют.
# Данные за 2010-03-11 уже существуют.
# Данные за 2010-03-14 уже существуют.
# Данные за 2010-03-15 уже существуют.
# Данные за 2010-03-16 уже существуют.
# Данные за 2010-03-17 уже существуют.
# Данные за 2010-03-18 уже существуют.
# Данные за 2010-03-21 уже существуют.
# Данные за 2010-03-22 уже существуют.
# Данные за 2010-03-23 уже существуют.
# Данные за 2010-03-24 уже существуют.
# Данные за 2010-03-25 уже существуют.
# Данные за 2010-03-28 уже существуют.
# Данные за 2010-03-29 уже существуют.
# Данные за 2010-03-30 уже существуют.
# Данные за 2010-03-31 уже существуют.
# Данные за 2010-04-01 уже существуют.
# Данные за 2010-04-04 уже существуют.
# Данные за 2010-04-05 уже существуют.
# Данные за 2010-04-06 уже существуют.
# Данные за 2010-04-07 уже существуют.
# Данные за 2010-04-08 уже существуют.
# Данные за 2010-04-11 уже существуют.
# Данные за 2010-04-12 уже существуют.
# Данные за 2010-04-13 уже существуют.
# Данные за 2010-04-14 уже существуют.
# Данные за 2010-04-15 уже существуют.
# Данные за 2010-04-18 уже существуют.
# Данные за 2010-04-19 уже существуют.
# Данные за 2010-04-20 уже существуют.
# Данные за 2010-04-21 уже существуют.
# Данные за 2010-04-22 уже существуют.
# Данные за 2010-04-25 уже существуют.
# Данные за 2010-04-26 уже существуют.
# Данные за 2010-04-27 уже существуют.
# Данные за 2010-04-28 уже существуют.
# Данные за 2010-04-29 уже существуют.
# Данные за 2010-05-03 уже существуют.
# Данные за 2010-05-04 уже существуют.
# Данные за 2010-05-05 уже существуют.
# Данные за 2010-05-06 уже существуют.
# Данные за 2010-05-10 уже существуют.
# Данные за 2010-05-11 уже существуют.
# Данные за 2010-05-12 уже существуют.
# Данные за 2010-05-13 уже существуют.
# Данные за 2010-05-16 уже существуют.
# Данные за 2010-05-17 уже существуют.
# Данные за 2010-05-18 уже существуют.
# Данные за 2010-05-19 уже существуют.
# Данные за 2010-05-20 уже существуют.
# Данные за 2010-05-23 уже существуют.
# Данные за 2010-05-24 уже существуют.
# Данные за 2010-05-25 уже существуют.
# Данные за 2010-05-26 уже существуют.
# Данные за 2010-05-27 уже существуют.
# Данные за 2010-05-30 уже существуют.
# Данные за 2010-05-31 уже существуют.
# Данные за 2010-06-01 уже существуют.
# Данные за 2010-06-02 уже существуют.
# Данные за 2010-06-03 уже существуют.
# Данные за 2010-06-06 уже существуют.
# Данные за 2010-06-07 уже существуют.
# Данные за 2010-06-08 уже существуют.
# Данные за 2010-06-09 уже существуют.
# Данные за 2010-06-10 уже существуют.
# Данные за 2010-06-14 уже существуют.
# Данные за 2010-06-15 уже существуют.
# Данные за 2010-06-16 уже существуют.
# Данные за 2010-06-17 уже существуют.
# Данные за 2010-06-20 уже существуют.
# Данные за 2010-06-21 уже существуют.
# Данные за 2010-06-22 уже существуют.
# Данные за 2010-06-23 уже существуют.
# Данные за 2010-06-24 уже существуют.
# Данные за 2010-06-27 уже существуют.
# Данные за 2010-06-28 уже существуют.
# Данные за 2010-06-29 уже существуют.
# Данные за 2010-06-30 уже существуют.
# Данные за 2010-07-01 уже существуют.
# Данные за 2010-07-04 уже существуют.
# Данные за 2010-07-05 уже существуют.
# Данные за 2010-07-06 уже существуют.
# Данные за 2010-07-07 уже существуют.
# Данные за 2010-07-08 уже существуют.
# Данные за 2010-07-11 уже существуют.
# Данные за 2010-07-12 уже существуют.
# Данные за 2010-07-13 уже существуют.
# Данные за 2010-07-14 уже существуют.
# Данные за 2010-07-15 уже существуют.
# Данные за 2010-07-18 уже существуют.
# Данные за 2010-07-19 уже существуют.
# Данные за 2010-07-20 уже существуют.
# Данные за 2010-07-21 уже существуют.
# Данные за 2010-07-22 уже существуют.
# Данные за 2010-07-25 уже существуют.
# Данные за 2010-07-26 уже существуют.
# Данные за 2010-07-27 уже существуют.
# Данные за 2010-07-28 уже существуют.
# Данные за 2010-07-29 уже существуют.
# Данные за 2010-08-01 уже существуют.
# Данные за 2010-08-02 уже существуют.
# Данные за 2010-08-03 уже существуют.
# Данные за 2010-08-04 уже существуют.
# Данные за 2010-08-05 уже существуют.
# Данные за 2010-08-08 уже существуют.
# Данные за 2010-08-09 уже существуют.
# Данные за 2010-08-10 уже существуют.
# Данные за 2010-08-11 уже существуют.
# Данные за 2010-08-12 уже существуют.
# Данные за 2010-08-15 уже существуют.
# Данные за 2010-08-16 уже существуют.
# Данные за 2010-08-17 уже существуют.
# Данные за 2010-08-18 уже существуют.
# Данные за 2010-08-19 уже существуют.
# Данные за 2010-08-22 уже существуют.
# Данные за 2010-08-23 уже существуют.
# Данные за 2010-08-24 уже существуют.
# Данные за 2010-08-25 уже существуют.
# Данные за 2010-08-26 уже существуют.
# Данные за 2010-08-29 уже существуют.
# Данные за 2010-08-30 уже существуют.
# Данные за 2010-08-31 уже существуют.
# Данные за 2010-09-01 уже существуют.
# Данные за 2010-09-02 уже существуют.
# Данные за 2010-09-05 уже существуют.
# Данные за 2010-09-06 уже существуют.
# Данные за 2010-09-07 уже существуют.
# Данные за 2010-09-08 уже существуют.
# Данные за 2010-09-09 уже существуют.
# Данные за 2010-09-12 уже существуют.
# Данные за 2010-09-13 уже существуют.
# Данные за 2010-09-14 уже существуют.
# Данные за 2010-09-15 уже существуют.
# Данные за 2010-09-16 уже существуют.
# Данные за 2010-09-19 уже существуют.
# Данные за 2010-09-20 уже существуют.
# Данные за 2010-09-21 уже существуют.
# Данные за 2010-09-22 уже существуют.
# Данные за 2010-09-23 уже существуют.
# Данные за 2010-09-26 уже существуют.
# Данные за 2010-09-27 уже существуют.
# Данные за 2010-09-28 уже существуют.
# Данные за 2010-09-29 уже существуют.
# Данные за 2010-09-30 уже существуют.
# Данные за 2010-10-03 уже существуют.
# Данные за 2010-10-04 уже существуют.
# Данные за 2010-10-05 уже существуют.
# Данные за 2010-10-06 уже существуют.
# Данные за 2010-10-07 уже существуют.
# Данные за 2010-10-10 уже существуют.
# Данные за 2010-10-11 уже существуют.
# Данные за 2010-10-12 уже существуют.
# Данные за 2010-10-13 уже существуют.
# Данные за 2010-10-14 уже существуют.
# Данные за 2010-10-17 уже существуют.
# Данные за 2010-10-18 уже существуют.
# Данные за 2010-10-19 уже существуют.
# Данные за 2010-10-20 уже существуют.
# Данные за 2010-10-21 уже существуют.
# Данные за 2010-10-24 уже существуют.
# Данные за 2010-10-25 уже существуют.
# Данные за 2010-10-26 уже существуют.
# Данные за 2010-10-27 уже существуют.
# Данные за 2010-10-28 уже существуют.
# Данные за 2010-10-31 уже существуют.
# Данные за 2010-11-01 уже существуют.
# Данные за 2010-11-02 уже существуют.
# Данные за 2010-11-07 уже существуют.
# Данные за 2010-11-08 уже существуют.
# Данные за 2010-11-09 уже существуют.
# Данные за 2010-11-10 уже существуют.
# Данные за 2010-11-11 уже существуют.
# Данные за 2010-11-14 уже существуют.
# Данные за 2010-11-15 уже существуют.
# Данные за 2010-11-16 уже существуют.
# Данные за 2010-11-17 уже существуют.
# Данные за 2010-11-18 уже существуют.
# Данные за 2010-11-21 уже существуют.
# Данные за 2010-11-22 уже существуют.
# Данные за 2010-11-23 уже существуют.
# Данные за 2010-11-24 уже существуют.
# Данные за 2010-11-25 уже существуют.
# Данные за 2010-11-28 уже существуют.
# Данные за 2010-11-29 уже существуют.
# Данные за 2010-11-30 уже существуют.
# Данные за 2010-12-01 уже существуют.
# Данные за 2010-12-02 уже существуют.
# Данные за 2010-12-05 уже существуют.
# Данные за 2010-12-06 уже существуют.
# Данные за 2010-12-07 уже существуют.
# Данные за 2010-12-08 уже существуют.
# Данные за 2010-12-09 уже существуют.
# Данные за 2010-12-12 уже существуют.
# Данные за 2010-12-13 уже существуют.
# Данные за 2010-12-14 уже существуют.
# Данные за 2010-12-15 уже существуют.
# Данные за 2010-12-16 уже существуют.
# Данные за 2010-12-19 уже существуют.
# Данные за 2010-12-20 уже существуют.
# Данные за 2010-12-21 уже существуют.
# Данные за 2010-12-22 уже существуют.
# Данные за 2010-12-23 уже существуют.
# Данные за 2010-12-26 уже существуют.
# Данные за 2010-12-27 уже существуют.
# Данные за 2010-12-28 уже существуют.
# Данные за 2010-12-29 уже существуют.
# Данные за 2011-01-10 уже существуют.
# Данные за 2011-01-11 уже существуют.
# Данные за 2011-01-12 уже существуют.
# Данные за 2011-01-13 уже существуют.
# Данные за 2011-01-16 уже существуют.
# Данные за 2011-01-17 уже существуют.
# Данные за 2011-01-18 уже существуют.
# Данные за 2011-01-19 уже существуют.
# Данные за 2011-01-20 уже существуют.
# Данные за 2011-01-23 уже существуют.
# Данные за 2011-01-24 уже существуют.
# Данные за 2011-01-25 уже существуют.
# Данные за 2011-01-26 уже существуют.
# Данные за 2011-01-27 уже существуют.
# Данные за 2011-01-30 уже существуют.
# Данные за 2011-01-31 уже существуют.
# Данные за 2011-02-01 уже существуют.
# Данные за 2011-02-02 уже существуют.
# Данные за 2011-02-03 уже существуют.
# Данные за 2011-02-06 уже существуют.
# Данные за 2011-02-07 уже существуют.
# Данные за 2011-02-08 уже существуют.
# Данные за 2011-02-09 уже существуют.
# Данные за 2011-02-10 уже существуют.
# Данные за 2011-02-13 уже существуют.
# Данные за 2011-02-14 уже существуют.
# Данные за 2011-02-15 уже существуют.
# Данные за 2011-02-16 уже существуют.
# Данные за 2011-02-17 уже существуют.
# Данные за 2011-02-20 уже существуют.
# Данные за 2011-02-21 уже существуют.
# Данные за 2011-02-23 уже существуют.
# Данные за 2011-02-24 уже существуют.
# Данные за 2011-02-27 уже существуют.
# Данные за 2011-02-28 уже существуют.
# Данные за 2011-03-01 уже существуют.
# Данные за 2011-03-02 уже существуют.
# Данные за 2011-03-03 уже существуют.
# Данные за 2011-03-08 уже существуют.
# Данные за 2011-03-09 уже существуют.
# Данные за 2011-03-10 уже существуют.
# Данные за 2011-03-13 уже существуют.
# Данные за 2011-03-14 уже существуют.
# Данные за 2011-03-15 уже существуют.
# Данные за 2011-03-16 уже существуют.
# Данные за 2011-03-17 уже существуют.
# Данные за 2011-03-20 уже существуют.
# Данные за 2011-03-21 уже существуют.
# Данные за 2011-03-22 уже существуют.
# Данные за 2011-03-23 уже существуют.
# Данные за 2011-03-24 уже существуют.
# Данные за 2011-03-27 уже существуют.
# Данные за 2011-03-28 уже существуют.
# Данные за 2011-03-29 уже существуют.
# Данные за 2011-03-30 уже существуют.
# Данные за 2011-03-31 уже существуют.
# Данные за 2011-04-03 уже существуют.
# Данные за 2011-04-04 уже существуют.
# Данные за 2011-04-05 уже существуют.
# Данные за 2011-04-06 уже существуют.
# Данные за 2011-04-07 уже существуют.
# Данные за 2011-04-10 уже существуют.
# Данные за 2011-04-11 уже существуют.
# Данные за 2011-04-12 уже существуют.
# Данные за 2011-04-13 уже существуют.
# Данные за 2011-04-14 уже существуют.
# Данные за 2011-04-17 уже существуют.
# Данные за 2011-04-18 уже существуют.
# Данные за 2011-04-19 уже существуют.
# Данные за 2011-04-20 уже существуют.
# Данные за 2011-04-21 уже существуют.
# Данные за 2011-04-24 уже существуют.
# Данные за 2011-04-25 уже существуют.
# Данные за 2011-04-26 уже существуют.
# Данные за 2011-04-27 уже существуют.
# Данные за 2011-04-28 уже существуют.
# Данные за 2011-05-02 уже существуют.
# Данные за 2011-05-03 уже существуют.
# Данные за 2011-05-04 уже существуют.
# Данные за 2011-05-05 уже существуют.
# Данные за 2011-05-09 уже существуют.
# Данные за 2011-05-10 уже существуют.
# Данные за 2011-05-11 уже существуют.
# Данные за 2011-05-12 уже существуют.
# Данные за 2011-05-15 уже существуют.
# Данные за 2011-05-16 уже существуют.
# Данные за 2011-05-17 уже существуют.
# Данные за 2011-05-18 уже существуют.
# Данные за 2011-05-19 уже существуют.
# Данные за 2011-05-22 уже существуют.
# Данные за 2011-05-23 уже существуют.
# Данные за 2011-05-24 уже существуют.
# Данные за 2011-05-25 уже существуют.
# Данные за 2011-05-26 уже существуют.
# Данные за 2011-05-29 уже существуют.
# Данные за 2011-05-30 уже существуют.
# Данные за 2011-05-31 уже существуют.
# Данные за 2011-06-01 уже существуют.
# Данные за 2011-06-02 уже существуют.
# Данные за 2011-06-05 уже существуют.
# Данные за 2011-06-06 уже существуют.
# Данные за 2011-06-07 уже существуют.
# Данные за 2011-06-08 уже существуют.
# Данные за 2011-06-09 уже существуют.
# Данные за 2011-06-13 уже существуют.
# Данные за 2011-06-14 уже существуют.
# Данные за 2011-06-15 уже существуют.
# Данные за 2011-06-16 уже существуют.
# Данные за 2011-06-19 уже существуют.
# Данные за 2011-06-20 уже существуют.
# Данные за 2011-06-21 уже существуют.
# Данные за 2011-06-22 уже существуют.
# Данные за 2011-06-23 уже существуют.
# Данные за 2011-06-26 уже существуют.
# Данные за 2011-06-27 уже существуют.
# Данные за 2011-06-28 уже существуют.
# Данные за 2011-06-29 уже существуют.
# Данные за 2011-06-30 уже существуют.
# Данные за 2011-07-03 уже существуют.
# Данные за 2011-07-04 уже существуют.
# Данные за 2011-07-05 уже существуют.
# Данные за 2011-07-06 уже существуют.
# Данные за 2011-07-07 уже существуют.
# Данные за 2011-07-10 уже существуют.
# Данные за 2011-07-11 уже существуют.
# Данные за 2011-07-12 уже существуют.
# Данные за 2011-07-13 уже существуют.
# Данные за 2011-07-14 уже существуют.
# Данные за 2011-07-17 уже существуют.
# Данные за 2011-07-18 уже существуют.
# Данные за 2011-07-19 уже существуют.
# Данные за 2011-07-20 уже существуют.
# Данные за 2011-07-21 уже существуют.
# Данные за 2011-07-24 уже существуют.
# Данные за 2011-07-25 уже существуют.
# Данные за 2011-07-26 уже существуют.
# Данные за 2011-07-27 уже существуют.
# Данные за 2011-07-28 уже существуют.
# Данные за 2011-07-31 уже существуют.
# Данные за 2011-08-01 уже существуют.
# Данные за 2011-08-02 уже существуют.
# Данные за 2011-08-03 уже существуют.
# Данные за 2011-08-04 уже существуют.
# Данные за 2011-08-07 уже существуют.
# Данные за 2011-08-08 уже существуют.
# Данные за 2011-08-09 уже существуют.
# Данные за 2011-08-10 уже существуют.
# Данные за 2011-08-11 уже существуют.
# Данные за 2011-08-14 уже существуют.
# Данные за 2011-08-15 уже существуют.
# Данные за 2011-08-16 уже существуют.
# Данные за 2011-08-17 уже существуют.
# Данные за 2011-08-18 уже существуют.
# Данные за 2011-08-21 уже существуют.
# Данные за 2011-08-22 уже существуют.
# Данные за 2011-08-23 уже существуют.
# Данные за 2011-08-24 уже существуют.
# Данные за 2011-08-25 уже существуют.
# Данные за 2011-08-28 уже существуют.
# Данные за 2011-08-29 уже существуют.
# Данные за 2011-08-30 уже существуют.
# Данные за 2011-08-31 уже существуют.
# Данные за 2011-09-01 уже существуют.
# Данные за 2011-09-04 уже существуют.
# Данные за 2011-09-05 уже существуют.
# Данные за 2011-09-06 уже существуют.
# Данные за 2011-09-07 уже существуют.
# Данные за 2011-09-08 уже существуют.
# Данные за 2011-09-11 уже существуют.
# Данные за 2011-09-12 уже существуют.
# Данные за 2011-09-13 уже существуют.
# Данные за 2011-09-14 уже существуют.
# Данные за 2011-09-15 уже существуют.
# Данные за 2011-09-18 уже существуют.
# Данные за 2011-09-19 уже существуют.
# Данные за 2011-09-20 уже существуют.
# Данные за 2011-09-21 уже существуют.
# Данные за 2011-09-22 уже существуют.
# Данные за 2011-09-25 уже существуют.
# Данные за 2011-09-26 уже существуют.
# Данные за 2011-09-27 уже существуют.
# Данные за 2011-09-28 уже существуют.
# Данные за 2011-09-29 уже существуют.
# Данные за 2011-10-02 уже существуют.
# Данные за 2011-10-03 уже существуют.
# Данные за 2011-10-04 уже существуют.
# Данные за 2011-10-05 уже существуют.
# Данные за 2011-10-06 уже существуют.
# Данные за 2011-10-09 уже существуют.
# Данные за 2011-10-10 уже существуют.
# Данные за 2011-10-11 уже существуют.
# Данные за 2011-10-12 уже существуют.
# Данные за 2011-10-13 уже существуют.
# Данные за 2011-10-16 уже существуют.
# Данные за 2011-10-17 уже существуют.
# Данные за 2011-10-18 уже существуют.
# Данные за 2011-10-19 уже существуют.
# Данные за 2011-10-20 уже существуют.
# Данные за 2011-10-23 уже существуют.
# Данные за 2011-10-24 уже существуют.
# Данные за 2011-10-25 уже существуют.
# Данные за 2011-10-26 уже существуют.
# Данные за 2011-10-27 уже существуют.
# Данные за 2011-10-30 уже существуют.
# Данные за 2011-10-31 уже существуют.
# Данные за 2011-11-01 уже существуют.
# Данные за 2011-11-02 уже существуют.
# Данные за 2011-11-06 уже существуют.
# Данные за 2011-11-07 уже существуют.
# Данные за 2011-11-08 уже существуют.
# Данные за 2011-11-09 уже существуют.
# Данные за 2011-11-10 уже существуют.
# Данные за 2011-11-13 уже существуют.
# Данные за 2011-11-14 уже существуют.
# Данные за 2011-11-15 уже существуют.
# Данные за 2011-11-16 уже существуют.
# Данные за 2011-11-17 уже существуют.
# Данные за 2011-11-20 уже существуют.
# Данные за 2011-11-21 уже существуют.
# Данные за 2011-11-22 уже существуют.
# Данные за 2011-11-23 уже существуют.
# Данные за 2011-11-24 уже существуют.
# Данные за 2011-11-27 уже существуют.
# Данные за 2011-11-28 уже существуют.
# Данные за 2011-11-29 уже существуют.
# Данные за 2011-11-30 уже существуют.
# Данные за 2011-12-01 уже существуют.
# Данные за 2011-12-04 уже существуют.
# Данные за 2011-12-05 уже существуют.
# Данные за 2011-12-06 уже существуют.
# Данные за 2011-12-07 уже существуют.
# Данные за 2011-12-08 уже существуют.
# Данные за 2011-12-11 уже существуют.
# Данные за 2011-12-12 уже существуют.
# Данные за 2011-12-13 уже существуют.
# Данные за 2011-12-14 уже существуют.
# Данные за 2011-12-15 уже существуют.
# Данные за 2011-12-18 уже существуют.
# Данные за 2011-12-19 уже существуют.
# Данные за 2011-12-20 уже существуют.
# Данные за 2011-12-21 уже существуют.
# Данные за 2011-12-22 уже существуют.
# Данные за 2011-12-25 уже существуют.
# Данные за 2011-12-26 уже существуют.
# Данные за 2011-12-27 уже существуют.
# Данные за 2011-12-28 уже существуют.
# Данные за 2011-12-29 уже существуют.
# Данные за 2012-01-02 уже существуют.
# Данные за 2012-01-03 уже существуют.
# Данные за 2012-01-04 уже существуют.
# Данные за 2012-01-05 уже существуют.
# Данные за 2012-01-09 уже существуют.
# Данные за 2012-01-10 уже существуют.
# Данные за 2012-01-11 уже существуют.
# Данные за 2012-01-12 уже существуют.
# Данные за 2012-01-15 уже существуют.
# Данные за 2012-01-16 уже существуют.
# Данные за 2012-01-17 уже существуют.
# Данные за 2012-01-18 уже существуют.
# Данные за 2012-01-19 уже существуют.
# Данные за 2012-01-22 уже существуют.
# Данные за 2012-01-23 уже существуют.
# Данные за 2012-01-24 уже существуют.
# Данные за 2012-01-25 уже существуют.
# Данные за 2012-01-26 уже существуют.
# Данные за 2012-01-29 уже существуют.
# Данные за 2012-01-30 уже существуют.
# Данные за 2012-01-31 уже существуют.
# Данные за 2012-02-01 уже существуют.
# Данные за 2012-02-02 уже существуют.
# Данные за 2012-02-05 уже существуют.
# Данные за 2012-02-06 уже существуют.
# Данные за 2012-02-07 уже существуют.
# Данные за 2012-02-08 уже существуют.
# Данные за 2012-02-09 уже существуют.
# Данные за 2012-02-12 уже существуют.
# Данные за 2012-02-13 уже существуют.
# Данные за 2012-02-14 уже существуют.
# Данные за 2012-02-15 уже существуют.
# Данные за 2012-02-16 уже существуют.
# Данные за 2012-02-19 уже существуют.
# Данные за 2012-02-20 уже существуют.
# Данные за 2012-02-21 уже существуют.
# Данные за 2012-02-23 уже существуют.
# Данные за 2012-02-26 уже существуют.
# Данные за 2012-02-27 уже существуют.
# Данные за 2012-02-28 уже существуют.
# Данные за 2012-02-29 уже существуют.
# Данные за 2012-03-01 уже существуют.
# Данные за 2012-03-04 уже существуют.
# Данные за 2012-03-05 уже существуют.
# Данные за 2012-03-06 уже существуют.
# Данные за 2012-03-11 уже существуют.
# Данные за 2012-03-12 уже существуют.
# Данные за 2012-03-13 уже существуют.
# Данные за 2012-03-14 уже существуют.
# Данные за 2012-03-15 уже существуют.
# Данные за 2012-03-18 уже существуют.
# Данные за 2012-03-19 уже существуют.
# Данные за 2012-03-20 уже существуют.
# Данные за 2012-03-21 уже существуют.
# Данные за 2012-03-22 уже существуют.
# Данные за 2012-03-25 уже существуют.
# Данные за 2012-03-26 уже существуют.
# Данные за 2012-03-27 уже существуют.
# Данные за 2012-03-28 уже существуют.
# Данные за 2012-03-29 уже существуют.
# Данные за 2012-04-01 уже существуют.
# Данные за 2012-04-02 уже существуют.
# Данные за 2012-04-03 уже существуют.
# Данные за 2012-04-04 уже существуют.
# Данные за 2012-04-05 уже существуют.
# Данные за 2012-04-08 уже существуют.
# Данные за 2012-04-09 уже существуют.
# Данные за 2012-04-10 уже существуют.
# Данные за 2012-04-11 уже существуют.
# Данные за 2012-04-12 уже существуют.
# Данные за 2012-04-15 уже существуют.
# Данные за 2012-04-16 уже существуют.
# Данные за 2012-04-17 уже существуют.
# Данные за 2012-04-18 уже существуют.
# Данные за 2012-04-19 уже существуют.
# Данные за 2012-04-22 уже существуют.
# Данные за 2012-04-23 уже существуют.
# Данные за 2012-04-24 уже существуют.
# Данные за 2012-04-25 уже существуют.
# Данные за 2012-04-26 уже существуют.
# Данные за 2012-05-01 уже существуют.
# Данные за 2012-05-02 уже существуют.
# Данные за 2012-05-03 уже существуют.
# Данные за 2012-05-06 уже существуют.
# Данные за 2012-05-07 уже существуют.
# Данные за 2012-05-09 уже существуют.
# Данные за 2012-05-10 уже существуют.
# Данные за 2012-05-13 уже существуют.
# Данные за 2012-05-14 уже существуют.
# Данные за 2012-05-15 уже существуют.
# Данные за 2012-05-16 уже существуют.
# Данные за 2012-05-17 уже существуют.
# Данные за 2012-05-20 уже существуют.
# Данные за 2012-05-21 уже существуют.
# Данные за 2012-05-22 уже существуют.
# Данные за 2012-05-23 уже существуют.
# Данные за 2012-05-24 уже существуют.
# Данные за 2012-05-27 уже существуют.
# Данные за 2012-05-28 уже существуют.
# Данные за 2012-05-29 уже существуют.
# Данные за 2012-05-30 уже существуют.
# Данные за 2012-05-31 уже существуют.
# Данные за 2012-06-03 уже существуют.
# Данные за 2012-06-04 уже существуют.
# Данные за 2012-06-05 уже существуют.
# Данные за 2012-06-06 уже существуют.
# Данные за 2012-06-07 уже существуют.
# Данные за 2012-06-12 уже существуют.
# Данные за 2012-06-13 уже существуют.
# Данные за 2012-06-14 уже существуют.
# Данные за 2012-06-17 уже существуют.
# Данные за 2012-06-18 уже существуют.
# Данные за 2012-06-19 уже существуют.
# Данные за 2012-06-20 уже существуют.
# Данные за 2012-06-21 уже существуют.
# Данные за 2012-06-24 уже существуют.
# Данные за 2012-06-25 уже существуют.
# Данные за 2012-06-26 уже существуют.
# Данные за 2012-06-27 уже существуют.
# Данные за 2012-06-28 уже существуют.
# Данные за 2012-07-01 уже существуют.
# Данные за 2012-07-02 уже существуют.
# Данные за 2012-07-03 уже существуют.
# Данные за 2012-07-04 уже существуют.
# Данные за 2012-07-05 уже существуют.
# Данные за 2012-07-08 уже существуют.
# Данные за 2012-07-09 уже существуют.
# Данные за 2012-07-10 уже существуют.
# Данные за 2012-07-11 уже существуют.
# Данные за 2012-07-12 уже существуют.
# Данные за 2012-07-15 уже существуют.
# Данные за 2012-07-16 уже существуют.
# Данные за 2012-07-17 уже существуют.
# Данные за 2012-07-18 уже существуют.
# Данные за 2012-07-19 уже существуют.
# Данные за 2012-07-22 уже существуют.
# Данные за 2012-07-23 уже существуют.
# Данные за 2012-07-24 уже существуют.
# Данные за 2012-07-25 уже существуют.
# Данные за 2012-07-26 уже существуют.
# Данные за 2012-07-29 уже существуют.
# Данные за 2012-07-30 уже существуют.
# Данные за 2012-07-31 уже существуют.
# Данные за 2012-08-01 уже существуют.
# Данные за 2012-08-02 уже существуют.
# Данные за 2012-08-05 уже существуют.
# Данные за 2012-08-06 уже существуют.
# Данные за 2012-08-07 уже существуют.
# Данные за 2012-08-08 уже существуют.
# Данные за 2012-08-09 уже существуют.
# Данные за 2012-08-12 уже существуют.
# Данные за 2012-08-13 уже существуют.
# Данные за 2012-08-14 уже существуют.
# Данные за 2012-08-15 уже существуют.
# Данные за 2012-08-16 уже существуют.
# Данные за 2012-08-19 уже существуют.
# Данные за 2012-08-20 уже существуют.
# Данные за 2012-08-21 уже существуют.
# Данные за 2012-08-22 уже существуют.
# Данные за 2012-08-23 уже существуют.
# Данные за 2012-08-26 уже существуют.
# Данные за 2012-08-27 уже существуют.
# Данные за 2012-08-28 уже существуют.
# Данные за 2012-08-29 уже существуют.
# Данные за 2012-08-30 уже существуют.
# Данные за 2012-09-02 уже существуют.
# Данные за 2012-09-03 уже существуют.
# Данные за 2012-09-04 уже существуют.
# Данные за 2012-09-05 уже существуют.
# Данные за 2012-09-06 уже существуют.
# Данные за 2012-09-09 уже существуют.
# Данные за 2012-09-10 уже существуют.
# Данные за 2012-09-11 уже существуют.
# Данные за 2012-09-12 уже существуют.
# Данные за 2012-09-13 уже существуют.
# Данные за 2012-09-16 уже существуют.
# Данные за 2012-09-17 уже существуют.
# Данные за 2012-09-18 уже существуют.
# Данные за 2012-09-19 уже существуют.
# Данные за 2012-09-20 уже существуют.
# Данные за 2012-09-23 уже существуют.
# Данные за 2012-09-24 уже существуют.
# Данные за 2012-09-25 уже существуют.
# Данные за 2012-09-26 уже существуют.
# Данные за 2012-09-27 уже существуют.
# Данные за 2012-09-30 уже существуют.
# Данные за 2012-10-01 уже существуют.
# Данные за 2012-10-02 уже существуют.
# Данные за 2012-10-03 уже существуют.
# Данные за 2012-10-04 уже существуют.
# Данные за 2012-10-07 уже существуют.
# Данные за 2012-10-08 уже существуют.
# Данные за 2012-10-09 уже существуют.
# Данные за 2012-10-10 уже существуют.
# Данные за 2012-10-11 уже существуют.
# Данные за 2012-10-14 уже существуют.
# Данные за 2012-10-15 уже существуют.
# Данные за 2012-10-16 уже существуют.
# Данные за 2012-10-17 уже существуют.
# Данные за 2012-10-18 уже существуют.
# Данные за 2012-10-21 уже существуют.
# Данные за 2012-10-22 уже существуют.
# Данные за 2012-10-23 уже существуют.
# Данные за 2012-10-24 уже существуют.
# Данные за 2012-10-25 уже существуют.
# Данные за 2012-10-28 уже существуют.
# Данные за 2012-10-29 уже существуют.
# Данные за 2012-10-30 уже существуют.
# Данные за 2012-10-31 уже существуют.
# Данные за 2012-11-01 уже существуют.
# Данные за 2012-11-05 уже существуют.
# Данные за 2012-11-06 уже существуют.
# Данные за 2012-11-07 уже существуют.
# Данные за 2012-11-08 уже существуют.
# Данные за 2012-11-11 уже существуют.
# Данные за 2012-11-12 уже существуют.
# Данные за 2012-11-13 уже существуют.
# Данные за 2012-11-14 уже существуют.
# Данные за 2012-11-15 уже существуют.
# Данные за 2012-11-18 уже существуют.
# Данные за 2012-11-19 уже существуют.
# Данные за 2012-11-20 уже существуют.
# Данные за 2012-11-21 уже существуют.
# Данные за 2012-11-22 уже существуют.
# Данные за 2012-11-25 уже существуют.
# Данные за 2012-11-26 уже существуют.
# Данные за 2012-11-27 уже существуют.
# Данные за 2012-11-28 уже существуют.
# Данные за 2012-11-29 уже существуют.
# Данные за 2012-12-02 уже существуют.
# Данные за 2012-12-03 уже существуют.
# Данные за 2012-12-04 уже существуют.
# Данные за 2012-12-05 уже существуют.
# Данные за 2012-12-06 уже существуют.
# Данные за 2012-12-09 уже существуют.
# Данные за 2012-12-10 уже существуют.
# Данные за 2012-12-11 уже существуют.
# Данные за 2012-12-12 уже существуют.
# Данные за 2012-12-13 уже существуют.
# Данные за 2012-12-16 уже существуют.
# Данные за 2012-12-17 уже существуют.
# Данные за 2012-12-18 уже существуют.
# Данные за 2012-12-19 уже существуют.
# Данные за 2012-12-20 уже существуют.
# Данные за 2012-12-23 уже существуют.
# Данные за 2012-12-24 уже существуют.
# Данные за 2012-12-25 уже существуют.
# Данные за 2012-12-26 уже существуют.
# Данные за 2012-12-27 уже существуют.
# Данные за 2013-01-07 уже существуют.
# Данные за 2013-01-08 уже существуют.
# Данные за 2013-01-09 уже существуют.
# Данные за 2013-01-10 уже существуют.
# Данные за 2013-01-13 уже существуют.
# Данные за 2013-01-14 уже существуют.
# Данные за 2013-01-15 уже существуют.
# Данные за 2013-01-16 уже существуют.
# Данные за 2013-01-17 уже существуют.
# Данные за 2013-01-20 уже существуют.
# Данные за 2013-01-21 уже существуют.
# Данные за 2013-01-22 уже существуют.
# Данные за 2013-01-23 уже существуют.
# Данные за 2013-01-24 уже существуют.
# Данные за 2013-01-27 уже существуют.
# Данные за 2013-01-28 уже существуют.
# Данные за 2013-01-29 уже существуют.
# Данные за 2013-01-30 уже существуют.
# Данные за 2013-01-31 уже существуют.
# Данные за 2013-02-03 уже существуют.
# Данные за 2013-02-04 уже существуют.
# Данные за 2013-02-05 уже существуют.
# Данные за 2013-02-06 уже существуют.
# Данные за 2013-02-07 уже существуют.
# Данные за 2013-02-10 уже существуют.
# Данные за 2013-02-11 уже существуют.
# Данные за 2013-02-12 уже существуют.
# Данные за 2013-02-13 уже существуют.
# Данные за 2013-02-14 уже существуют.
# Данные за 2013-02-17 уже существуют.
# Данные за 2013-02-18 уже существуют.
# Данные за 2013-02-19 уже существуют.
# Данные за 2013-02-20 уже существуют.
# Данные за 2013-02-21 уже существуют.
# Данные за 2013-02-24 уже существуют.
# Данные за 2013-02-25 уже существуют.
# Данные за 2013-02-26 уже существуют.
# Данные за 2013-02-27 уже существуют.
# Данные за 2013-02-28 уже существуют.
# Данные за 2013-03-03 уже существуют.
# Данные за 2013-03-04 уже существуют.
# Данные за 2013-03-05 уже существуют.
# Данные за 2013-03-06 уже существуют.
# Данные за 2013-03-10 уже существуют.
# Данные за 2013-03-11 уже существуют.
# Данные за 2013-03-12 уже существуют.
# Данные за 2013-03-13 уже существуют.
# Данные за 2013-03-14 уже существуют.
# Данные за 2013-03-17 уже существуют.
# Данные за 2013-03-18 уже существуют.
# Данные за 2013-03-19 уже существуют.
# Данные за 2013-03-20 уже существуют.
# Данные за 2013-03-21 уже существуют.
# Данные за 2013-03-24 уже существуют.
# Данные за 2013-03-25 уже существуют.
# Данные за 2013-03-26 уже существуют.
# Данные за 2013-03-27 уже существуют.
# Данные за 2013-03-28 уже существуют.
# Данные за 2013-03-31 уже существуют.
# Данные за 2013-04-01 уже существуют.
# Данные за 2013-04-02 уже существуют.
# Данные за 2013-04-03 уже существуют.
# Данные за 2013-04-04 уже существуют.
# Данные за 2013-04-07 уже существуют.
# Данные за 2013-04-08 уже существуют.
# Данные за 2013-04-09 уже существуют.
# Данные за 2013-04-10 уже существуют.
# Данные за 2013-04-11 уже существуют.
# Данные за 2013-04-14 уже существуют.
# Данные за 2013-04-15 уже существуют.
# Данные за 2013-04-16 уже существуют.
# Данные за 2013-04-17 уже существуют.
# Данные за 2013-04-18 уже существуют.
# Данные за 2013-04-21 уже существуют.
# Данные за 2013-04-22 уже существуют.
# Данные за 2013-04-23 уже существуют.
# Данные за 2013-04-24 уже существуют.
# Данные за 2013-04-25 уже существуют.
# Данные за 2013-04-28 уже существуют.
# Данные за 2013-04-29 уже существуют.
# Данные за 2013-05-01 уже существуют.
# Данные за 2013-05-02 уже существуют.
# Данные за 2013-05-05 уже существуют.
# Данные за 2013-05-06 уже существуют.
# Данные за 2013-05-07 уже существуют.
# Данные за 2013-05-09 уже существуют.
# Данные за 2013-05-12 уже существуют.
# Данные за 2013-05-13 уже существуют.
# Данные за 2013-05-14 уже существуют.
# Данные за 2013-05-15 уже существуют.
# Данные за 2013-05-16 уже существуют.
# Данные за 2013-05-19 уже существуют.
# Данные за 2013-05-20 уже существуют.
# Данные за 2013-05-21 уже существуют.
# Данные за 2013-05-22 уже существуют.
# Данные за 2013-05-23 уже существуют.
# Данные за 2013-05-26 уже существуют.
# Данные за 2013-05-27 уже существуют.
# Данные за 2013-05-28 уже существуют.
# Данные за 2013-05-29 уже существуют.
# Данные за 2013-05-30 уже существуют.
# Данные за 2013-06-02 уже существуют.
# Данные за 2013-06-03 уже существуют.
# Данные за 2013-06-04 уже существуют.
# Данные за 2013-06-05 уже существуют.
# Данные за 2013-06-06 уже существуют.
# Данные за 2013-06-09 уже существуют.
# Данные за 2013-06-10 уже существуют.
# Данные за 2013-06-12 уже существуют.
# Данные за 2013-06-13 уже существуют.
# Данные за 2013-06-16 уже существуют.
# Данные за 2013-06-17 уже существуют.
# Данные за 2013-06-18 уже существуют.
# Данные за 2013-06-19 уже существуют.
# Данные за 2013-06-20 уже существуют.
# Данные за 2013-06-23 уже существуют.
# Данные за 2013-06-24 уже существуют.
# Данные за 2013-06-25 уже существуют.
# Данные за 2013-06-26 уже существуют.
# Данные за 2013-06-27 уже существуют.
# Данные за 2013-06-30 уже существуют.
# Данные за 2013-07-01 уже существуют.
# Данные за 2013-07-02 уже существуют.
# Данные за 2013-07-03 уже существуют.
# Данные за 2013-07-04 уже существуют.
# Данные за 2013-07-07 уже существуют.
# Данные за 2013-07-08 уже существуют.
# Данные за 2013-07-09 уже существуют.
# Данные за 2013-07-10 уже существуют.
# Данные за 2013-07-11 уже существуют.
# Данные за 2013-07-14 уже существуют.
# Данные за 2013-07-15 уже существуют.
# Данные за 2013-07-16 уже существуют.
# Данные за 2013-07-17 уже существуют.
# Данные за 2013-07-18 уже существуют.
# Данные за 2013-07-21 уже существуют.
# Данные за 2013-07-22 уже существуют.
# Данные за 2013-07-23 уже существуют.
# Данные за 2013-07-24 уже существуют.
# Данные за 2013-07-25 уже существуют.
# Данные за 2013-07-28 уже существуют.
# Данные за 2013-07-29 уже существуют.
# Данные за 2013-07-30 уже существуют.
# Данные за 2013-07-31 уже существуют.
# Данные за 2013-08-01 уже существуют.
# Данные за 2013-08-04 уже существуют.
# Данные за 2013-08-05 уже существуют.
# Данные за 2013-08-06 уже существуют.
# Данные за 2013-08-07 уже существуют.
# Данные за 2013-08-08 уже существуют.
# Данные за 2013-08-11 уже существуют.
# Данные за 2013-08-12 уже существуют.
# Данные за 2013-08-13 уже существуют.
# Данные за 2013-08-14 уже существуют.
# Данные за 2013-08-15 уже существуют.
# Данные за 2013-08-18 уже существуют.
# Данные за 2013-08-19 уже существуют.
# Данные за 2013-08-20 уже существуют.
# Данные за 2013-08-21 уже существуют.
# Данные за 2013-08-22 уже существуют.
# Данные за 2013-08-25 уже существуют.
# Данные за 2013-08-26 уже существуют.
# Данные за 2013-08-27 уже существуют.
# Данные за 2013-08-28 уже существуют.
# Данные за 2013-08-29 уже существуют.
# Данные за 2013-09-01 уже существуют.
# Данные за 2013-09-02 уже существуют.
# Данные за 2013-09-03 уже существуют.
# Данные за 2013-09-04 уже существуют.
# Данные за 2013-09-05 уже существуют.
# Данные за 2013-09-08 уже существуют.
# Данные за 2013-09-09 уже существуют.
# Данные за 2013-09-10 уже существуют.
# Данные за 2013-09-11 уже существуют.
# Данные за 2013-09-12 уже существуют.
# Данные за 2013-09-15 уже существуют.
# Данные за 2013-09-16 уже существуют.
# Данные за 2013-09-17 уже существуют.
# Данные за 2013-09-18 уже существуют.
# Данные за 2013-09-19 уже существуют.
# Данные за 2013-09-22 уже существуют.
# Данные за 2013-09-23 уже существуют.
# Данные за 2013-09-24 уже существуют.
# Данные за 2013-09-25 уже существуют.
# Данные за 2013-09-26 уже существуют.
# Данные за 2013-09-29 уже существуют.
# Данные за 2013-09-30 уже существуют.
# Данные за 2013-10-01 уже существуют.
# Данные за 2013-10-02 уже существуют.
# Данные за 2013-10-03 уже существуют.
# Данные за 2013-10-06 уже существуют.
# Данные за 2013-10-07 уже существуют.
# Данные за 2013-10-08 уже существуют.
# Данные за 2013-10-09 уже существуют.
# Данные за 2013-10-10 уже существуют.
# Данные за 2013-10-13 уже существуют.
# Данные за 2013-10-14 уже существуют.
# Данные за 2013-10-15 уже существуют.
# Данные за 2013-10-16 уже существуют.
# Данные за 2013-10-17 уже существуют.
# Данные за 2013-10-20 уже существуют.
# Данные за 2013-10-21 уже существуют.
# Данные за 2013-10-22 уже существуют.
# Данные за 2013-10-23 уже существуют.
# Данные за 2013-10-24 уже существуют.
# Данные за 2013-10-27 уже существуют.
# Данные за 2013-10-28 уже существуют.
# Данные за 2013-10-29 уже существуют.
# Данные за 2013-10-30 уже существуют.
# Данные за 2013-10-31 уже существуют.
# Данные за 2013-11-04 уже существуют.
# Данные за 2013-11-05 уже существуют.
# Данные за 2013-11-06 уже существуют.
# Данные за 2013-11-07 уже существуют.
# Данные за 2013-11-10 уже существуют.
# Данные за 2013-11-11 уже существуют.
# Данные за 2013-11-12 уже существуют.
# Данные за 2013-11-13 уже существуют.
# Данные за 2013-11-14 уже существуют.
# Данные за 2013-11-17 уже существуют.
# Данные за 2013-11-18 уже существуют.
# Данные за 2013-11-19 уже существуют.
# Данные за 2013-11-20 уже существуют.
# Данные за 2013-11-21 уже существуют.
# Данные за 2013-11-24 уже существуют.
# Данные за 2013-11-25 уже существуют.
# Данные за 2013-11-26 уже существуют.
# Данные за 2013-11-27 уже существуют.
# Данные за 2013-11-28 уже существуют.
# Данные за 2013-12-01 уже существуют.
# Данные за 2013-12-02 уже существуют.
# Данные за 2013-12-03 уже существуют.
# Данные за 2013-12-04 уже существуют.
# Данные за 2013-12-05 уже существуют.
# Данные за 2013-12-08 уже существуют.
# Данные за 2013-12-09 уже существуют.
# Данные за 2013-12-10 уже существуют.
# Данные за 2013-12-11 уже существуют.
# Данные за 2013-12-12 уже существуют.
# Данные за 2013-12-15 уже существуют.
# Данные за 2013-12-16 уже существуют.
# Данные за 2013-12-17 уже существуют.
# Данные за 2013-12-18 уже существуют.
# Данные за 2013-12-19 уже существуют.
# Данные за 2013-12-22 уже существуют.
# Данные за 2013-12-23 уже существуют.
# Данные за 2013-12-24 уже существуют.
# Данные за 2013-12-25 уже существуют.
# Данные за 2013-12-26 уже существуют.
# Данные за 2013-12-29 уже существуют.
# Данные за 2014-01-05 уже существуют.
# Данные за 2014-01-07 уже существуют.
# Данные за 2014-01-08 уже существуют.
# Данные за 2014-01-09 уже существуют.
# Данные за 2014-01-12 уже существуют.
# Данные за 2014-01-13 уже существуют.
# Данные за 2014-01-14 уже существуют.
# Данные за 2014-01-15 уже существуют.
# Данные за 2014-01-16 уже существуют.
# Данные за 2014-01-19 уже существуют.
# Данные за 2014-01-20 уже существуют.
# Данные за 2014-01-21 уже существуют.
# Данные за 2014-01-22 уже существуют.
# Данные за 2014-01-23 уже существуют.
# Данные за 2014-01-26 уже существуют.
# Данные за 2014-01-27 уже существуют.
# Данные за 2014-01-28 уже существуют.
# Данные за 2014-01-29 уже существуют.
# Данные за 2014-01-30 уже существуют.
# Данные за 2014-02-02 уже существуют.
# Данные за 2014-02-03 уже существуют.
# Данные за 2014-02-04 уже существуют.
# Данные за 2014-02-05 уже существуют.
# Данные за 2014-02-06 уже существуют.
# Данные за 2014-02-09 уже существуют.
# Данные за 2014-02-10 уже существуют.
# Данные за 2014-02-11 уже существуют.
# Данные за 2014-02-12 уже существуют.
# Данные за 2014-02-13 уже существуют.
# Данные за 2014-02-16 уже существуют.
# Данные за 2014-02-17 уже существуют.
# Данные за 2014-02-18 уже существуют.
# Данные за 2014-02-19 уже существуют.
# Данные за 2014-02-20 уже существуют.
# Данные за 2014-02-23 уже существуют.
# Данные за 2014-02-24 уже существуют.
# Данные за 2014-02-25 уже существуют.
# Данные за 2014-02-26 уже существуют.
# Данные за 2014-02-27 уже существуют.
# Данные за 2014-03-02 уже существуют.
# Данные за 2014-03-03 уже существуют.
# Данные за 2014-03-04 уже существуют.
# Данные за 2014-03-05 уже существуют.
# Данные за 2014-03-06 уже существуют.
# Данные за 2014-03-10 уже существуют.
# Данные за 2014-03-11 уже существуют.
# Данные за 2014-03-12 уже существуют.
# Данные за 2014-03-13 уже существуют.
# Данные за 2014-03-16 уже существуют.
# Данные за 2014-03-17 уже существуют.
# Данные за 2014-03-18 уже существуют.
# Данные за 2014-03-19 уже существуют.
# Данные за 2014-03-20 уже существуют.
# Данные за 2014-03-23 уже существуют.
# Данные за 2014-03-24 уже существуют.
# Данные за 2014-03-25 уже существуют.
# Данные за 2014-03-26 уже существуют.
# Данные за 2014-03-27 уже существуют.
# Данные за 2014-03-30 уже существуют.
# Данные за 2014-03-31 уже существуют.
# Данные за 2014-04-01 уже существуют.
# Данные за 2014-04-02 уже существуют.
# Данные за 2014-04-03 уже существуют.
# Данные за 2014-04-06 уже существуют.
# Данные за 2014-04-07 уже существуют.
# Данные за 2014-04-08 уже существуют.
# Данные за 2014-04-09 уже существуют.
# Данные за 2014-04-10 уже существуют.
# Данные за 2014-04-13 уже существуют.
# Данные за 2014-04-14 уже существуют.
# Данные за 2014-04-15 уже существуют.
# Данные за 2014-04-16 уже существуют.
# Данные за 2014-04-17 уже существуют.
# Данные за 2014-04-20 уже существуют.
# Данные за 2014-04-21 уже существуют.
# Данные за 2014-04-22 уже существуют.
# Данные за 2014-04-23 уже существуют.
# Данные за 2014-04-24 уже существуют.
# Данные за 2014-04-27 уже существуют.
# Данные за 2014-04-28 уже существуют.
# Данные за 2014-04-29 уже существуют.
# Данные за 2014-05-04 уже существуют.
# Данные за 2014-05-05 уже существуют.
# Данные за 2014-05-06 уже существуют.
# Данные за 2014-05-07 уже существуют.
# Данные за 2014-05-11 уже существуют.
# Данные за 2014-05-12 уже существуют.
# Данные за 2014-05-13 уже существуют.
# Данные за 2014-05-14 уже существуют.
# Данные за 2014-05-15 уже существуют.
# Данные за 2014-05-18 уже существуют.
# Данные за 2014-05-19 уже существуют.
# Данные за 2014-05-20 уже существуют.
# Данные за 2014-05-21 уже существуют.
# Данные за 2014-05-22 уже существуют.
# Данные за 2014-05-25 уже существуют.
# Данные за 2014-05-26 уже существуют.
# Данные за 2014-05-27 уже существуют.
# Данные за 2014-05-28 уже существуют.
# Данные за 2014-05-29 уже существуют.
# Данные за 2014-06-01 уже существуют.
# Данные за 2014-06-02 уже существуют.
# Данные за 2014-06-03 уже существуют.
# Данные за 2014-06-04 уже существуют.
# Данные за 2014-06-05 уже существуют.
# Данные за 2014-06-08 уже существуют.
# Данные за 2014-06-09 уже существуют.
# Данные за 2014-06-10 уже существуют.
# Данные за 2014-06-15 уже существуют.
# Данные за 2014-06-16 уже существуют.
# Данные за 2014-06-17 уже существуют.
# Данные за 2014-06-18 уже существуют.
# Данные за 2014-06-19 уже существуют.
# Данные за 2014-06-22 уже существуют.
# Данные за 2014-06-23 уже существуют.
# Данные за 2014-06-24 уже существуют.
# Данные за 2014-06-25 уже существуют.
# Данные за 2014-06-26 уже существуют.
# Данные за 2014-06-29 уже существуют.
# Данные за 2014-06-30 уже существуют.
# Данные за 2014-07-01 уже существуют.
# Данные за 2014-07-02 уже существуют.
# Данные за 2014-07-03 уже существуют.
# Данные за 2014-07-06 уже существуют.
# Данные за 2014-07-07 уже существуют.
# Данные за 2014-07-08 уже существуют.
# Данные за 2014-07-09 уже существуют.
# Данные за 2014-07-10 уже существуют.
# Данные за 2014-07-13 уже существуют.
# Данные за 2014-07-14 уже существуют.
# Данные за 2014-07-15 уже существуют.
# Данные за 2014-07-16 уже существуют.
# Данные за 2014-07-17 уже существуют.
# Данные за 2014-07-20 уже существуют.
# Данные за 2014-07-21 уже существуют.
# Данные за 2014-07-22 уже существуют.
# Данные за 2014-07-23 уже существуют.
# Данные за 2014-07-24 уже существуют.
# Данные за 2014-07-27 уже существуют.
# Данные за 2014-07-28 уже существуют.
# Данные за 2014-07-29 уже существуют.
# Данные за 2014-07-30 уже существуют.
# Данные за 2014-07-31 уже существуют.
# Данные за 2014-08-03 уже существуют.
# Данные за 2014-08-04 уже существуют.
# Данные за 2014-08-05 уже существуют.
# Данные за 2014-08-06 уже существуют.
# Данные за 2014-08-07 уже существуют.
# Данные за 2014-08-10 уже существуют.
# Данные за 2014-08-11 уже существуют.
# Данные за 2014-08-12 уже существуют.
# Данные за 2014-08-13 уже существуют.
# Данные за 2014-08-14 уже существуют.
# Данные за 2014-08-17 уже существуют.
# Данные за 2014-08-18 уже существуют.
# Данные за 2014-08-19 уже существуют.
# Данные за 2014-08-20 уже существуют.
# Данные за 2014-08-21 уже существуют.
# Данные за 2014-08-24 уже существуют.
# Данные за 2014-08-25 уже существуют.
# Данные за 2014-08-26 уже существуют.
# Данные за 2014-08-27 уже существуют.
# Данные за 2014-08-28 уже существуют.
# Данные за 2014-08-31 уже существуют.
# Данные за 2014-09-01 уже существуют.
# Данные за 2014-09-02 уже существуют.
# Данные за 2014-09-03 уже существуют.
# Данные за 2014-09-04 уже существуют.
# Данные за 2014-09-07 уже существуют.
# Данные за 2014-09-08 уже существуют.
# Данные за 2014-09-09 уже существуют.
# Данные за 2014-09-10 уже существуют.
# Данные за 2014-09-11 уже существуют.
# Данные за 2014-09-14 уже существуют.
# Данные за 2014-09-15 уже существуют.
# Данные за 2014-09-16 уже существуют.
# Данные за 2014-09-17 уже существуют.
# Данные за 2014-09-18 уже существуют.
# Данные за 2014-09-21 уже существуют.
# Данные за 2014-09-22 уже существуют.
# Данные за 2014-09-23 уже существуют.
# Данные за 2014-09-24 уже существуют.
# Данные за 2014-09-25 уже существуют.
# Данные за 2014-09-28 уже существуют.
# Данные за 2014-09-29 уже существуют.
# Данные за 2014-09-30 уже существуют.
# Данные за 2014-10-01 уже существуют.
# Данные за 2014-10-02 уже существуют.
# Данные за 2014-10-05 уже существуют.
# Данные за 2014-10-06 уже существуют.
# Данные за 2014-10-07 уже существуют.
# Данные за 2014-10-08 уже существуют.
# Данные за 2014-10-09 уже существуют.
# Данные за 2014-10-12 уже существуют.
# Данные за 2014-10-13 уже существуют.
# Данные за 2014-10-14 уже существуют.
# Данные за 2014-10-15 уже существуют.
# Данные за 2014-10-16 уже существуют.
# Данные за 2014-10-19 уже существуют.
# Данные за 2014-10-20 уже существуют.
# Данные за 2014-10-21 уже существуют.
# Данные за 2014-10-22 уже существуют.
# Данные за 2014-10-23 уже существуют.
# Данные за 2014-10-26 уже существуют.
# Данные за 2014-10-27 уже существуют.
# Данные за 2014-10-28 уже существуют.
# Данные за 2014-10-29 уже существуют.
# Данные за 2014-10-30 уже существуют.
# Данные за 2014-11-04 уже существуют.
# Данные за 2014-11-05 уже существуют.
# Данные за 2014-11-06 уже существуют.
# Данные за 2014-11-09 уже существуют.
# Данные за 2014-11-10 уже существуют.
# Данные за 2014-11-11 уже существуют.
# Данные за 2014-11-12 уже существуют.
# Данные за 2014-11-13 уже существуют.
# Данные за 2014-11-16 уже существуют.
# Данные за 2014-11-17 уже существуют.
# Данные за 2014-11-18 уже существуют.
# Данные за 2014-11-19 уже существуют.
# Данные за 2014-11-20 уже существуют.
# Данные за 2014-11-23 уже существуют.
# Данные за 2014-11-24 уже существуют.
# Данные за 2014-11-25 уже существуют.
# Данные за 2014-11-26 уже существуют.
# Данные за 2014-11-27 уже существуют.
# Данные за 2014-11-30 уже существуют.
# Данные за 2014-12-01 уже существуют.
# Данные за 2014-12-02 уже существуют.
# Данные за 2014-12-03 уже существуют.
# Данные за 2014-12-04 уже существуют.
# Данные за 2014-12-07 уже существуют.
# Данные за 2014-12-08 уже существуют.
# Данные за 2014-12-09 уже существуют.
# Данные за 2014-12-10 уже существуют.
# Данные за 2014-12-11 уже существуют.
# Данные за 2014-12-14 уже существуют.
# Данные за 2014-12-15 уже существуют.
# Данные за 2014-12-16 уже существуют.
# Данные за 2014-12-17 уже существуют.
# Данные за 2014-12-18 уже существуют.
# Данные за 2014-12-21 уже существуют.
# Данные за 2014-12-22 уже существуют.
# Данные за 2014-12-23 уже существуют.
# Данные за 2014-12-24 уже существуют.
# Данные за 2014-12-25 уже существуют.
# Данные за 2014-12-28 уже существуют.
# Данные за 2014-12-29 уже существуют.
# Данные за 2015-01-04 уже существуют.
# Данные за 2015-01-05 уже существуют.
# Данные за 2015-01-07 уже существуют.
# Данные за 2015-01-08 уже существуют.
# Данные за 2015-01-11 уже существуют.
# Данные за 2015-01-12 уже существуют.
# Данные за 2015-01-13 уже существуют.
# Данные за 2015-01-14 уже существуют.
# Данные за 2015-01-15 уже существуют.
# Данные за 2015-01-18 уже существуют.
# Данные за 2015-01-19 уже существуют.
# Данные за 2015-01-20 уже существуют.
# Данные за 2015-01-21 уже существуют.
# Данные за 2015-01-22 уже существуют.
# Данные за 2015-01-25 уже существуют.
# Данные за 2015-01-26 уже существуют.
# Данные за 2015-01-27 уже существуют.
# Данные за 2015-01-28 уже существуют.
# Данные за 2015-01-29 уже существуют.
# Данные за 2015-02-01 уже существуют.
# Данные за 2015-02-02 уже существуют.
# Данные за 2015-02-03 уже существуют.
# Данные за 2015-02-04 уже существуют.
# Данные за 2015-02-05 уже существуют.
# Данные за 2015-02-08 уже существуют.
# Данные за 2015-02-09 уже существуют.
# Данные за 2015-02-10 уже существуют.
# Данные за 2015-02-11 уже существуют.
# Данные за 2015-02-12 уже существуют.
# Данные за 2015-02-15 уже существуют.
# Данные за 2015-02-16 уже существуют.
# Данные за 2015-02-17 уже существуют.
# Данные за 2015-02-18 уже существуют.
# Данные за 2015-02-19 уже существуют.
# Данные за 2015-02-23 уже существуют.
# Данные за 2015-02-24 уже существуют.
# Данные за 2015-02-25 уже существуют.
# Данные за 2015-02-26 уже существуют.
# Данные за 2015-03-01 уже существуют.
# Данные за 2015-03-02 уже существуют.
# Данные за 2015-03-03 уже существуют.
# Данные за 2015-03-04 уже существуют.
# Данные за 2015-03-05 уже существуют.
# Данные за 2015-03-09 уже существуют.
# Данные за 2015-03-10 уже существуют.
# Данные за 2015-03-11 уже существуют.
# Данные за 2015-03-12 уже существуют.
# Данные за 2015-03-15 уже существуют.
# Данные за 2015-03-16 уже существуют.
# Данные за 2015-03-17 уже существуют.
# Данные за 2015-03-18 уже существуют.
# Данные за 2015-03-19 уже существуют.
# Данные за 2015-03-22 уже существуют.
# Данные за 2015-03-23 уже существуют.
# Данные за 2015-03-24 уже существуют.
# Данные за 2015-03-25 уже существуют.
# Данные за 2015-03-26 уже существуют.
# Данные за 2015-03-29 уже существуют.
# Данные за 2015-03-30 уже существуют.
# Данные за 2015-03-31 уже существуют.
# Данные за 2015-04-01 уже существуют.
# Данные за 2015-04-02 уже существуют.
# Данные за 2015-04-05 уже существуют.
# Данные за 2015-04-06 уже существуют.
# Данные за 2015-04-07 уже существуют.
# Данные за 2015-04-08 уже существуют.
# Данные за 2015-04-09 уже существуют.
# Данные за 2015-04-12 уже существуют.
# Данные за 2015-04-13 уже существуют.
# Данные за 2015-04-14 уже существуют.
# Данные за 2015-04-15 уже существуют.
# Данные за 2015-04-16 уже существуют.
# Данные за 2015-04-19 уже существуют.
# Данные за 2015-04-20 уже существуют.
# Данные за 2015-04-21 уже существуют.
# Данные за 2015-04-22 уже существуют.
# Данные за 2015-04-23 уже существуют.
# Данные за 2015-04-26 уже существуют.
# Данные за 2015-04-27 уже существуют.
# Данные за 2015-04-28 уже существуют.
# Данные за 2015-04-29 уже существуют.
# Данные за 2015-05-03 уже существуют.
# Данные за 2015-05-04 уже существуют.
# Данные за 2015-05-05 уже существуют.
# Данные за 2015-05-06 уже существуют.
# Данные за 2015-05-07 уже существуют.
# Данные за 2015-05-11 уже существуют.
# Данные за 2015-05-12 уже существуют.
# Данные за 2015-05-13 уже существуют.
# Данные за 2015-05-14 уже существуют.
# Данные за 2015-05-17 уже существуют.
# Данные за 2015-05-18 уже существуют.
# ...
# Данные за 2020-08-12 уже существуют.
# Данные за 2020-08-13 уже существуют.
# Данные за 2020-08-16 уже существуют.
# Данные за 2020-08-17 уже существуют.
# Данные за 2020-08-18 уже существуют.
# Данные за 2020-08-19 уже существуют.
# Данные за 2020-08-20 уже существуют.
# Данные за 2020-08-23 уже существуют.
# Данные за 2020-08-24 уже существуют.
# Данные за 2020-08-25 уже существуют.
# Данные за 2020-08-26 уже существуют.
# Данные за 2020-08-27 уже существуют.
# Данные за 2020-08-30 уже существуют.
# Данные за 2020-08-31 уже существуют.
# Данные за 2020-09-01 уже существуют.
# Данные за 2020-09-02 уже существуют.
# Данные за 2020-09-03 уже существуют.
# Данные за 2020-09-06 уже существуют.
# Данные за 2020-09-07 уже существуют.
# Данные за 2020-09-08 уже существуют.
# Данные за 2020-09-09 уже существуют.
# Данные за 2020-09-10 уже существуют.
# Данные за 2020-09-13 уже существуют.
# Данные за 2020-09-14 уже существуют.
# Данные за 2020-09-15 уже существуют.
# Данные за 2020-09-16 уже существуют.
# Данные за 2020-09-17 уже существуют.
# Данные за 2020-09-20 уже существуют.
# Данные за 2020-09-21 уже существуют.
# Данные за 2020-09-22 уже существуют.
# Данные за 2020-09-23 уже существуют.
# Данные за 2020-09-24 уже существуют.
# Данные за 2020-09-27 уже существуют.
# Данные за 2020-09-28 уже существуют.
# Данные за 2020-09-29 уже существуют.
# Данные за 2020-09-30 уже существуют.
# Данные за 2020-10-01 уже существуют.
# Данные за 2020-10-04 уже существуют.
# Данные за 2020-10-05 уже существуют.
# Данные за 2020-10-06 уже существуют.
# Данные за 2020-10-07 уже существуют.
# Данные за 2020-10-08 уже существуют.
# Данные за 2020-10-11 уже существуют.
# Данные за 2020-10-12 уже существуют.
# Данные за 2020-10-13 уже существуют.
# Данные за 2020-10-14 уже существуют.
# Данные за 2020-10-15 уже существуют.
# Данные за 2020-10-18 уже существуют.
# Данные за 2020-10-19 уже существуют.
# Данные за 2020-10-20 уже существуют.
# Данные за 2020-10-21 уже существуют.
# Данные за 2020-10-22 уже существуют.
# Данные за 2020-10-25 уже существуют.
# Данные за 2020-10-26 уже существуют.
# Данные за 2020-10-27 уже существуют.
# Данные за 2020-10-28 уже существуют.
# Данные за 2020-10-29 уже существуют.
# Данные за 2020-11-01 уже существуют.
# Данные за 2020-11-02 уже существуют.
# Данные за 2020-11-04 уже существуют.
# Данные за 2020-11-05 уже существуют.
# Данные за 2020-11-08 уже существуют.
# Данные за 2020-11-09 уже существуют.
# Данные за 2020-11-10 уже существуют.
# Данные за 2020-11-11 уже существуют.
# Данные за 2020-11-12 уже существуют.
# Данные за 2020-11-15 уже существуют.
# Данные за 2020-11-16 уже существуют.
# Данные за 2020-11-17 уже существуют.
# Данные за 2020-11-18 уже существуют.
# Данные за 2020-11-19 уже существуют.
# Данные за 2020-11-22 уже существуют.
# Данные за 2020-11-23 уже существуют.
# Данные за 2020-11-24 уже существуют.
# Данные за 2020-11-25 уже существуют.
# Данные за 2020-11-26 уже существуют.
# Данные за 2020-11-29 уже существуют.
# Данные за 2020-11-30 уже существуют.
# Данные за 2020-12-01 уже существуют.
# Данные за 2020-12-02 уже существуют.
# Данные за 2020-12-03 уже существуют.
# Данные за 2020-12-06 уже существуют.
# Данные за 2020-12-07 уже существуют.
# Данные за 2020-12-08 уже существуют.
# Данные за 2020-12-09 уже существуют.
# Данные за 2020-12-10 уже существуют.
# Данные за 2020-12-13 уже существуют.
# Данные за 2020-12-14 уже существуют.
# Данные за 2020-12-15 уже существуют.
# Данные за 2020-12-16 уже существуют.
# Данные за 2020-12-17 уже существуют.
# Данные за 2020-12-20 уже существуют.
# Данные за 2020-12-21 уже существуют.
# Данные за 2020-12-22 уже существуют.
# Данные за 2020-12-23 уже существуют.
# Данные за 2020-12-24 уже существуют.
# Данные за 2020-12-27 уже существуют.
# Данные за 2020-12-28 уже существуют.
# Данные за 2020-12-29 уже существуют.
# Данные за 2021-01-03 уже существуют.
# Данные за 2021-01-04 уже существуют.
# Данные за 2021-01-05 уже существуют.
# Данные за 2021-01-07 уже существуют.
# Данные за 2021-01-10 уже существуют.
# Данные за 2021-01-11 уже существуют.
# Данные за 2021-01-12 уже существуют.
# Данные за 2021-01-13 уже существуют.
# Данные за 2021-01-14 уже существуют.
# Данные за 2021-01-17 уже существуют.
# Данные за 2021-01-18 уже существуют.
# Данные за 2021-01-19 уже существуют.
# Данные за 2021-01-20 уже существуют.
# Данные за 2021-01-21 уже существуют.
# Данные за 2021-01-24 уже существуют.
# Данные за 2021-01-25 уже существуют.
# Данные за 2021-01-26 уже существуют.
# Данные за 2021-01-27 уже существуют.
# Данные за 2021-01-28 уже существуют.
# Данные за 2021-01-31 уже существуют.
# Данные за 2021-02-01 уже существуют.
# Данные за 2021-02-02 уже существуют.
# Данные за 2021-02-03 уже существуют.
# Данные за 2021-02-04 уже существуют.
# Данные за 2021-02-07 уже существуют.
# Данные за 2021-02-08 уже существуют.
# Данные за 2021-02-09 уже существуют.
# Данные за 2021-02-10 уже существуют.
# Данные за 2021-02-11 уже существуют.
# Данные за 2021-02-14 уже существуют.
# Данные за 2021-02-15 уже существуют.
# Данные за 2021-02-16 уже существуют.
# Данные за 2021-02-17 уже существуют.
# Данные за 2021-02-18 уже существуют.
# Данные за 2021-02-21 уже существуют.
# Данные за 2021-02-23 уже существуют.
# Данные за 2021-02-24 уже существуют.
# Данные за 2021-02-25 уже существуют.
# Данные за 2021-02-28 уже существуют.
# Данные за 2021-03-01 уже существуют.
# Данные за 2021-03-02 уже существуют.
# Данные за 2021-03-03 уже существуют.
# Данные за 2021-03-04 уже существуют.
# Данные за 2021-03-08 уже существуют.
# Данные за 2021-03-09 уже существуют.
# Данные за 2021-03-10 уже существуют.
# Данные за 2021-03-11 уже существуют.
# Данные за 2021-03-14 уже существуют.
# Данные за 2021-03-15 уже существуют.
# Данные за 2021-03-16 уже существуют.
# Данные за 2021-03-17 уже существуют.
# Данные за 2021-03-18 уже существуют.
# Данные за 2021-03-21 уже существуют.
# Данные за 2021-03-22 уже существуют.
# Данные за 2021-03-23 уже существуют.
# Данные за 2021-03-24 уже существуют.
# Данные за 2021-03-25 уже существуют.
# Данные за 2021-03-28 уже существуют.
# Данные за 2021-03-29 уже существуют.
# Данные за 2021-03-30 уже существуют.
# Данные за 2021-03-31 уже существуют.
# Данные за 2021-04-01 уже существуют.
# Данные за 2021-04-04 уже существуют.
# Данные за 2021-04-05 уже существуют.
# Данные за 2021-04-06 уже существуют.
# Данные за 2021-04-07 уже существуют.
# Данные за 2021-04-08 уже существуют.
# Данные за 2021-04-11 уже существуют.
# Данные за 2021-04-12 уже существуют.
# Данные за 2021-04-13 уже существуют.
# Данные за 2021-04-14 уже существуют.
# Данные за 2021-04-15 уже существуют.
# Данные за 2021-04-18 уже существуют.
# Данные за 2021-04-19 уже существуют.
# Данные за 2021-04-20 уже существуют.
# Данные за 2021-04-21 уже существуют.
# Данные за 2021-04-22 уже существуют.
# Данные за 2021-04-25 уже существуют.
# Данные за 2021-04-26 уже существуют.
# Данные за 2021-04-27 уже существуют.
# Данные за 2021-04-28 уже существуют.
# Данные за 2021-04-29 уже существуют.
# Данные за 2021-05-03 уже существуют.
# Данные за 2021-05-04 уже существуют.
# Данные за 2021-05-05 уже существуют.
# Данные за 2021-05-06 уже существуют.
# Данные за 2021-05-09 уже существуют.
# Данные за 2021-05-10 уже существуют.
# Данные за 2021-05-11 уже существуют.
# Данные за 2021-05-12 уже существуют.
# Данные за 2021-05-13 уже существуют.
# Данные за 2021-05-16 уже существуют.
# Данные за 2021-05-17 уже существуют.
# Данные за 2021-05-18 уже существуют.
# Данные за 2021-05-19 уже существуют.
# Данные за 2021-05-20 уже существуют.
# Данные за 2021-05-23 уже существуют.
# Данные за 2021-05-24 уже существуют.
# Данные за 2021-05-25 уже существуют.
# Данные за 2021-05-26 уже существуют.
# Данные за 2021-05-27 уже существуют.
# Данные за 2021-05-30 уже существуют.
# Данные за 2021-05-31 уже существуют.
# Данные за 2021-06-01 уже существуют.
# Данные за 2021-06-02 уже существуют.
# Данные за 2021-06-03 уже существуют.
# Данные за 2021-06-06 уже существуют.
# Данные за 2021-06-07 уже существуют.
# Данные за 2021-06-08 уже существуют.
# Данные за 2021-06-09 уже существуют.
# Данные за 2021-06-10 уже существуют.
# Данные за 2021-06-13 уже существуют.
# Данные за 2021-06-14 уже существуют.
# Данные за 2021-06-15 уже существуют.
# Данные за 2021-06-16 уже существуют.
# Данные за 2021-06-17 уже существуют.
# Данные за 2021-06-20 уже существуют.
# Данные за 2021-06-21 уже существуют.
# Данные за 2021-06-22 уже существуют.
# Данные за 2021-06-23 уже существуют.
# Данные за 2021-06-24 уже существуют.
# Данные за 2021-06-27 уже существуют.
# Данные за 2021-06-28 уже существуют.
# Данные за 2021-06-29 уже существуют.
# Данные за 2021-06-30 уже существуют.
# Данные за 2021-07-01 уже существуют.
# Данные за 2021-07-04 уже существуют.
# Данные за 2021-07-05 уже существуют.
# Данные за 2021-07-06 уже существуют.
# Данные за 2021-07-07 уже существуют.
# Данные за 2021-07-08 уже существуют.
# Данные за 2021-07-11 уже существуют.
# Данные за 2021-07-12 уже существуют.
# Данные за 2021-07-13 уже существуют.
# Данные за 2021-07-14 уже существуют.
# Данные за 2021-07-15 уже существуют.
# Данные за 2021-07-18 уже существуют.
# Данные за 2021-07-19 уже существуют.
# Данные за 2021-07-20 уже существуют.
# Данные за 2021-07-21 уже существуют.
# Данные за 2021-07-22 уже существуют.
# Данные за 2021-07-25 уже существуют.
# Данные за 2021-07-26 уже существуют.
# Данные за 2021-07-27 уже существуют.
# Данные за 2021-07-28 уже существуют.
# Данные за 2021-07-29 уже существуют.
# Данные за 2021-08-01 уже существуют.
# Данные за 2021-08-02 уже существуют.
# Данные за 2021-08-03 уже существуют.
# Данные за 2021-08-04 уже существуют.
# Данные за 2021-08-05 уже существуют.
# Данные за 2021-08-08 уже существуют.
# Данные за 2021-08-09 уже существуют.
# Данные за 2021-08-10 уже существуют.
# Данные за 2021-08-11 уже существуют.
# Данные за 2021-08-12 уже существуют.
# Данные за 2021-08-15 уже существуют.
# Данные за 2021-08-16 уже существуют.
# Данные за 2021-08-17 уже существуют.
# Данные за 2021-08-18 уже существуют.
# Данные за 2021-08-19 уже существуют.
# Данные за 2021-08-22 уже существуют.
# Данные за 2021-08-23 уже существуют.
# Данные за 2021-08-24 уже существуют.
# Данные за 2021-08-25 уже существуют.
# Данные за 2021-08-26 уже существуют.
# Данные за 2021-08-29 уже существуют.
# Данные за 2021-08-30 уже существуют.
# Данные за 2021-08-31 уже существуют.
# Данные за 2021-09-01 уже существуют.
# Данные за 2021-09-02 уже существуют.
# Данные за 2021-09-05 уже существуют.
# Данные за 2021-09-06 уже существуют.
# Данные за 2021-09-07 уже существуют.
# Данные за 2021-09-08 уже существуют.
# Данные за 2021-09-09 уже существуют.
# Данные за 2021-09-12 уже существуют.
# Данные за 2021-09-13 уже существуют.
# Данные за 2021-09-14 уже существуют.
# Данные за 2021-09-15 уже существуют.
# Данные за 2021-09-16 уже существуют.
# Данные за 2021-09-19 уже существуют.
# Данные за 2021-09-20 уже существуют.
# Данные за 2021-09-21 уже существуют.
# Данные за 2021-09-22 уже существуют.
# Данные за 2021-09-23 уже существуют.
# Данные за 2021-09-26 уже существуют.
# Данные за 2021-09-27 уже существуют.
# Данные за 2021-09-28 уже существуют.
# Данные за 2021-09-29 уже существуют.
# Данные за 2021-09-30 уже существуют.
# Данные за 2021-10-03 уже существуют.
# Данные за 2021-10-04 уже существуют.
# Данные за 2021-10-05 уже существуют.
# Данные за 2021-10-06 уже существуют.
# Данные за 2021-10-07 уже существуют.
# Данные за 2021-10-10 уже существуют.
# Данные за 2021-10-11 уже существуют.
# Данные за 2021-10-12 уже существуют.
# Данные за 2021-10-13 уже существуют.
# Данные за 2021-10-14 уже существуют.
# Данные за 2021-10-17 уже существуют.
# Данные за 2021-10-18 уже существуют.
# Данные за 2021-10-19 уже существуют.
# Данные за 2021-10-20 уже существуют.
# Данные за 2021-10-21 уже существуют.
# Данные за 2021-10-24 уже существуют.
# Данные за 2021-10-25 уже существуют.
# Данные за 2021-10-26 уже существуют.
# Данные за 2021-10-27 уже существуют.
# Данные за 2021-10-28 уже существуют.
# Данные за 2021-10-31 уже существуют.
# Данные за 2021-11-01 уже существуют.
# Данные за 2021-11-02 уже существуют.
# Данные за 2021-11-04 уже существуют.
# Данные за 2021-11-07 уже существуют.
# Данные за 2021-11-08 уже существуют.
# Данные за 2021-11-09 уже существуют.
# Данные за 2021-11-10 уже существуют.
# Данные за 2021-11-11 уже существуют.
# Данные за 2021-11-14 уже существуют.
# Данные за 2021-11-15 уже существуют.
# Данные за 2021-11-16 уже существуют.
# Данные за 2021-11-17 уже существуют.
# Данные за 2021-11-18 уже существуют.
# Данные за 2021-11-21 уже существуют.
# Данные за 2021-11-22 уже существуют.
# Данные за 2021-11-23 уже существуют.
# Данные за 2021-11-24 уже существуют.
# Данные за 2021-11-25 уже существуют.
# Данные за 2021-11-28 уже существуют.
# Данные за 2021-11-29 уже существуют.
# Данные за 2021-11-30 уже существуют.
# Данные за 2021-12-01 уже существуют.
# Данные за 2021-12-02 уже существуют.
# Данные за 2021-12-05 уже существуют.
# Данные за 2021-12-06 уже существуют.
# Данные за 2021-12-07 уже существуют.
# Данные за 2021-12-08 уже существуют.
# Данные за 2021-12-09 уже существуют.
# Данные за 2021-12-12 уже существуют.
# Данные за 2021-12-13 уже существуют.
# Данные за 2021-12-14 уже существуют.
# Данные за 2021-12-15 уже существуют.
# Данные за 2021-12-16 уже существуют.
# Данные за 2021-12-19 уже существуют.
# Данные за 2021-12-20 уже существуют.
# Данные за 2021-12-21 уже существуют.
# Данные за 2021-12-22 уже существуют.
# Данные за 2021-12-23 уже существуют.
# Данные за 2021-12-26 уже существуют.
# Данные за 2021-12-27 уже существуют.
# Данные за 2021-12-28 уже существуют.
# Данные за 2021-12-29 уже существуют.
# Данные за 2022-01-02 уже существуют.
# Данные за 2022-01-03 уже существуют.
# Данные за 2022-01-04 уже существуют.
# Данные за 2022-01-05 уже существуют.
# Данные за 2022-01-09 уже существуют.
# Данные за 2022-01-10 уже существуют.
# Данные за 2022-01-11 уже существуют.
# Данные за 2022-01-12 уже существуют.
# Данные за 2022-01-13 уже существуют.
# Данные за 2022-01-16 уже существуют.
# Данные за 2022-01-17 уже существуют.
# Данные за 2022-01-18 уже существуют.
# Данные за 2022-01-19 уже существуют.
# Данные за 2022-01-20 уже существуют.
# Данные за 2022-01-23 уже существуют.
# Данные за 2022-01-24 уже существуют.
# Данные за 2022-01-25 уже существуют.
# Данные за 2022-01-26 уже существуют.
# Данные за 2022-01-27 уже существуют.
# Данные за 2022-01-30 уже существуют.
# Данные за 2022-01-31 уже существуют.
# Данные за 2022-02-01 уже существуют.
# Данные за 2022-02-02 уже существуют.
# Данные за 2022-02-03 уже существуют.
# Данные за 2022-02-06 уже существуют.
# Данные за 2022-02-07 уже существуют.
# Данные за 2022-02-08 уже существуют.
# Данные за 2022-02-09 уже существуют.
# Данные за 2022-02-10 уже существуют.
# Данные за 2022-02-13 уже существуют.
# Данные за 2022-02-14 уже существуют.
# Данные за 2022-02-15 уже существуют.
# Данные за 2022-02-16 уже существуют.
# Данные за 2022-02-17 уже существуют.
# Данные за 2022-02-20 уже существуют.
# Данные за 2022-02-21 уже существуют.
# Данные за 2022-02-23 уже существуют.
# Данные за 2022-02-24 уже существуют.
# Данные за 2022-03-23 уже существуют.
# Данные за 2022-03-24 уже существуют.
# Данные за 2022-03-27 уже существуют.
# Данные за 2022-03-28 уже существуют.
# Данные за 2022-03-29 уже существуют.
# Данные за 2022-03-30 уже существуют.
# Данные за 2022-03-31 уже существуют.
# Данные за 2022-04-03 уже существуют.
# Данные за 2022-04-04 уже существуют.
# Данные за 2022-04-05 уже существуют.
# Данные за 2022-04-06 уже существуют.
# Данные за 2022-04-07 уже существуют.
# Данные за 2022-04-10 уже существуют.
# Данные за 2022-04-11 уже существуют.
# Данные за 2022-04-12 уже существуют.
# Данные за 2022-04-13 уже существуют.
# Данные за 2022-04-14 уже существуют.
# Данные за 2022-04-17 уже существуют.
# Данные за 2022-04-18 уже существуют.
# Данные за 2022-04-19 уже существуют.
# Данные за 2022-04-20 уже существуют.
# Данные за 2022-04-21 уже существуют.
# Данные за 2022-04-24 уже существуют.
# Данные за 2022-04-25 уже существуют.
# Данные за 2022-04-26 уже существуют.
# Данные за 2022-04-27 уже существуют.
# Данные за 2022-04-28 уже существуют.
# Данные за 2022-05-03 уже существуют.
# Данные за 2022-05-04 уже существуют.
# Данные за 2022-05-05 уже существуют.
# Данные за 2022-05-10 уже существуют.
# Данные за 2022-05-11 уже существуют.
# Данные за 2022-05-12 уже существуют.
# Данные за 2022-05-15 уже существуют.
# Данные за 2022-05-16 уже существуют.
# Данные за 2022-05-17 уже существуют.
# Данные за 2022-05-18 уже существуют.
# Данные за 2022-05-19 уже существуют.
# Данные за 2022-05-22 уже существуют.
# Данные за 2022-05-23 уже существуют.
# Данные за 2022-10-09 уже существуют.

# %%
https://colab.research.google.com/drive/1dgE8BfEQl7yB7G8xS2TkRaVAmc3joTvE?usp=sharing

# %%
https://docs-python.ru/packages/modul-pandas-analiz-dannykh-python/explode-series-dataframe/
